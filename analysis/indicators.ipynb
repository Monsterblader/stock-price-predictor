# %% [markdown]
# https://www.thepythoncode.com/article/stock-price-prediction-in-python-using-tensorflow-2-and-keras

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, Bidirectional
from tensorflow.keras.callbacks import ModelCheckpoint, TensorBoard, EarlyStopping
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from yahoo_fin import stock_info as si
from collections import deque

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import time
import os
import random

# %%
# set seed, so we can get the same results after rerunning several times
np.random.seed(314)
tf.random.set_seed(314)
random.seed(314)

# %%
def load_data(ticker, n_steps=50, scale=True, shuffle=True, lookup_step=1, 
                test_size=0.2, feature_columns=['adjclose', 'volume', 'open', 'high', 'low']):
    """
    Loads data from Yahoo Finance source, as well as scaling, shuffling, normalizing and splitting.
    Params:
        ticker (str/pd.DataFrame): the ticker you want to load, examples include AAPL, TESL, etc.
        n_steps (int): the historical sequence length (i.e window size) used to predict, default is 50
        scale (bool): whether to scale prices from 0 to 1, default is True
        shuffle (bool): whether to shuffle the data, default is True
        lookup_step (int): the future lookup step to predict, default is 1 (e.g next day)
        test_size (float): ratio for test data, default is 0.2 (20% testing data)
        feature_columns (list): the list of features to use to feed into the model, default is everything grabbed from yahoo_fin
    """
    # see if ticker is already a loaded stock from yahoo finance
    if isinstance(ticker, str):
        # load it from yahoo_fin library
        df = si.get_data(ticker)
    elif isinstance(ticker, pd.DataFrame):
        # already loaded, use it directly
        df = ticker
    else:
        raise TypeError("ticker can be either a str or a `pd.DataFrame` instances")
    # this will contain all the elements we want to return from this function
    result = {}
    # we will also return the original dataframe itself
    result['df'] = df.copy()
    # make sure that the passed feature_columns exist in the dataframe
    for col in feature_columns:
        assert col in df.columns, f"'{col}' does not exist in the dataframe."
    if scale:
        column_scaler = {}
        # scale the data (prices) from 0 to 1
        for column in feature_columns:
            scaler = preprocessing.MinMaxScaler()
            df[column] = scaler.fit_transform(np.expand_dims(df[column].values, axis=1))
            column_scaler[column] = scaler
        # add the MinMaxScaler instances to the result returned
        result["column_scaler"] = column_scaler
    # add the target column (label) by shifting by `lookup_step`
    df['future'] = df['adjclose'].shift(-lookup_step)
    # last `lookup_step` columns contains NaN in future column
    # get them before droping NaNs
    last_sequence = np.array(df[feature_columns].tail(lookup_step))
    # drop NaNs
    df.dropna(inplace=True)
    sequence_data = []
    sequences = deque(maxlen=n_steps)
    for entry, target in zip(df[feature_columns].values, df['future'].values):
        sequences.append(entry)
        if len(sequences) == n_steps:
            sequence_data.append([np.array(sequences), target])
    # get the last sequence by appending the last `n_step` sequence with `lookup_step` sequence
    # for instance, if n_steps=50 and lookup_step=10, last_sequence should be of 60 (that is 50+10) length
    # this last_sequence will be used to predict future stock prices not available in the dataset
    last_sequence = list(sequences) + list(last_sequence)
    last_sequence = np.array(last_sequence)
    # add to result
    result['last_sequence'] = last_sequence
    # construct the X's and y's
    X, y = [], []
    for seq, target in sequence_data:
        X.append(seq)
        y.append(target)
    # convert to numpy arrays
    X = np.array(X)
    y = np.array(y)
    # reshape X to fit the neural network
    X = X.reshape((X.shape[0], X.shape[2], X.shape[1]))
    # split the dataset
    result["X_train"], result["X_test"], result["y_train"], result["y_test"] = train_test_split(X, y, 
                                                                               test_size=test_size, shuffle=shuffle)
    # split_point = int(len(X) * (1 - test_size))
    # result["X_train"], result["X_test"], result["y_train"], result["y_test"] = X[:split_point], X[split_point:], y[:split_point], y[split_point:]
    # return the result
    return result

# %%
def create_model(sequence_length, units=256, cell=LSTM, n_layers=2, dropout=0.3,
                loss="mean_absolute_error", optimizer="rmsprop", bidirectional=False):
    model = Sequential()
    for i in range(n_layers):
        if i == 0:
            # first layer
            if bidirectional:
                model.add(Bidirectional(cell(units, return_sequences=True), input_shape=(None, sequence_length)))
            else:
                model.add(cell(units, return_sequences=True, input_shape=(None, sequence_length)))
        elif i == n_layers - 1:
            # last layer
            if bidirectional:
                model.add(Bidirectional(cell(units, return_sequences=False)))
            else:
                model.add(cell(units, return_sequences=False))
        else:
            # hidden layers
            if bidirectional:
                model.add(Bidirectional(cell(units, return_sequences=True)))
            else:
                model.add(cell(units, return_sequences=True))
        # add dropout after each layer
        model.add(Dropout(dropout))
    model.add(Dense(1, activation="linear"))
    model.compile(loss=loss, metrics=["mean_absolute_error"], optimizer=optimizer)
    return model

# %%
# Window size or the sequence length
N_STEPS = 20
# Lookup step, 1 is the next day
LOOKUP_STEP = 10
# test ratio size, 0.2 is 20%
TEST_SIZE = 0.2
# features to use
FEATURE_COLUMNS = ["adjclose", "volume", "open", "high", "low"]
# date now
date_now = time.strftime("%Y-%m-%d")
### model parameters
N_LAYERS = 3
# LSTM cell
CELL = LSTM
# 256 LSTM neurons
UNITS = 256
# 40% dropout
DROPOUT = 0.4
# whether to use bidirectional RNNs
BIDIRECTIONAL = True
### training parameters
# mean absolute error loss
# LOSS = "mae"
# huber loss
LOSS = "huber_loss"
OPTIMIZER = "adam"
BATCH_SIZE = 64
EPOCHS = 400
# Tesla stock market
ticker = "TSLA"
ticker_data_filename = os.path.join("data", f"{ticker}_{date_now}.csv")
# model name to save, making it as unique as possible based on parameters
model_name = f"{date_now}_{ticker}-{LOSS}-{OPTIMIZER}-{CELL.__name__}-seq-{N_STEPS}-step-{LOOKUP_STEP}-layers-{N_LAYERS}-units-{UNITS}"
if BIDIRECTIONAL:
    model_name += "-b"

# %%
# create these folders if they does not exist
if not os.path.isdir("results"):
    os.mkdir("results")
if not os.path.isdir("logs"):
    os.mkdir("logs")
if not os.path.isdir("data"):
    os.mkdir("data")

# %%
# load the data
data = load_data(ticker, N_STEPS, lookup_step=LOOKUP_STEP, test_size=TEST_SIZE, feature_columns=FEATURE_COLUMNS)
# save the dataframe
data["df"].to_csv(ticker_data_filename)
# construct the model
model = create_model(N_STEPS, loss=LOSS, units=UNITS, cell=CELL, n_layers=N_LAYERS,
                    dropout=DROPOUT, optimizer=OPTIMIZER, bidirectional=BIDIRECTIONAL)
# some tensorflow callbacks
checkpointer = ModelCheckpoint(os.path.join("results", model_name + ".h5"), save_weights_only=True, save_best_only=True, verbose=1)
tensorboard = TensorBoard(log_dir=os.path.join("logs", model_name))
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=50)

history = model.fit(data["X_train"], data["y_train"],
                    batch_size=BATCH_SIZE,
                    epochs=EPOCHS,
                    validation_data=(data["X_test"], data["y_test"]),
                    callbacks=[checkpointer, tensorboard, es],
                    verbose=1)
model.save(os.path.join("results", model_name) + ".h5")
# Out:
# error: 0.0095
# Epoch 299/400
# 32/33 [============================>.] - ETA: 0s - loss: 1.3558e-04 - mean_absolute_error: 0.0101
# Epoch 00299: val_loss did not improve from 0.00009
# 33/33 [==============================] - 3s 80ms/step - loss: 1.3415e-04 - mean_absolute_error: 0.0101 - val_loss: 1.7760e-04 - val_mean_absolute_error: 0.0094
# Epoch 300/400
# 33/33 [==============================] - ETA: 0s - loss: 1.9012e-04 - mean_absolute_error: 0.0109
# Epoch 00300: val_loss did not improve from 0.00009
# 33/33 [==============================] - 3s 82ms/step - loss: 1.9012e-04 - mean_absolute_error: 0.0109 - val_loss: 1.1993e-04 - val_mean_absolute_error: 0.0100
# Epoch 301/400
# 33/33 [==============================] - ETA: 0s - loss: 1.6151e-04 - mean_absolute_error: 0.0104
# Epoch 00301: val_loss did not improve from 0.00009
# 33/33 [==============================] - 3s 82ms/step - loss: 1.6151e-04 - mean_absolute_error: 0.0104 - val_loss: 1.1119e-04 - val_mean_absolute_error: 0.0100
# Epoch 302/400
# 32/33 [============================>.] - ETA: 0s - loss: 1.5094e-04 - mean_absolute_error: 0.0101
# Epoch 00302: val_loss did not improve from 0.00009
# 33/33 [==============================] - 3s 81ms/step - loss: 1.5089e-04 - mean_absolute_error: 0.0101 - val_loss: 1.3343e-04 - val_mean_absolute_error: 0.0101
# Epoch 303/400
# 33/33 [==============================] - ETA: 0s - loss: 1.7251e-04 - mean_absolute_error: 0.0107
# Epoch 00303: val_loss did not improve from 0.00009
# 33/33 [==============================] - 3s 80ms/step - loss: 1.7251e-04 - mean_absolute_error: 0.0107 - val_loss: 1.2329e-04 - val_mean_absolute_error: 0.0087
# Epoch 304/400
# 32/33 [============================>.] - ETA: 0s - loss: 1.4526e-04 - mean_absolute_error: 0.0101
# Epoch 00304: val_loss did not improve from 0.00009
# 33/33 [==============================] - 3s 81ms/step - loss: 1.5503e-04 - mean_absolute_error: 0.0102 - val_loss: 1.0416e-04 - val_mean_absolute_error: 0.0078
# Epoch 305/400
# 33/33 [==============================] - ETA: 0s - loss: 1.5025e-04 - mean_absolute_error: 0.0099
# Epoch 00305: val_loss did not improve from 0.00009
# 33/33 [==============================] - 3s 82ms/step - loss: 1.5025e-04 - mean_absolute_error: 0.0099 - val_loss: 1.2470e-04 - val_mean_absolute_error: 0.0082
# Epoch 306/400
# 33/33 [==============================] - ETA: 0s - loss: 1.6469e-04 - mean_absolute_error: 0.0108
# Epoch 00306: val_loss did not improve from 0.00009
# 33/33 [==============================] - 3s 83ms/step - loss: 1.6469e-04 - mean_absolute_error: 0.0108 - val_loss: 1.0261e-04 - val_mean_absolute_error: 0.0081
# Epoch 307/400
# 33/33 [==============================] - ETA: 0s - loss: 1.2875e-04 - mean_absolute_error: 0.0096
# Epoch 00307: val_loss improved from 0.00009 to 0.00008, saving model to results/2020-12-02_TSLA-huber_loss-adam-LSTM-seq-20-step-10-layers-3-units-256-b.h5
# 33/33 [==============================] - 3s 84ms/step - loss: 1.2875e-04 - mean_absolute_error: 0.0096 - val_loss: 7.6544e-05 - val_mean_absolute_error: 0.0075
# Epoch 308/400
# 33/33 [==============================] - ETA: 0s - loss: 1.2605e-04 - mean_absolute_error: 0.0095
# Epoch 00308: val_loss did not improve from 0.00008
# 33/33 [==============================] - 3s 83ms/step - loss: 1.2605e-04 - mean_absolute_error: 0.0095 - val_loss: 9.2060e-05 - val_mean_absolute_error: 0.0076
# Epoch 309/400
# 32/33 [============================>.] - ETA: 0s - loss: 1.4507e-04 - mean_absolute_error: 0.0099
# Epoch 00309: val_loss improved from 0.00008 to 0.00007, saving model to results/2020-12-02_TSLA-huber_loss-adam-LSTM-seq-20-step-10-layers-3-units-256-b.h5
# 33/33 [==============================] - 3s 82ms/step - loss: 1.4501e-04 - mean_absolute_error: 0.0099 - val_loss: 6.7665e-05 - val_mean_absolute_error: 0.0078
# Epoch 310/400
# 33/33 [==============================] - ETA: 0s - loss: 1.2153e-04 - mean_absolute_error: 0.0099
# Epoch 00310: val_loss did not improve from 0.00007
# 33/33 [==============================] - 3s 82ms/step - loss: 1.2153e-04 - mean_absolute_error: 0.0099 - val_loss: 1.0690e-04 - val_mean_absolute_error: 0.0092
# Epoch 311/400
# 32/33 [============================>.] - ETA: 0s - loss: 1.8012e-04 - mean_absolute_error: 0.0105
# Epoch 00311: val_loss did not improve from 0.00007
# 33/33 [==============================] - 3s 80ms/step - loss: 1.8395e-04 - mean_absolute_error: 0.0106 - val_loss: 1.6471e-04 - val_mean_absolute_error: 0.0096
# Epoch 312/400
# 33/33 [==============================] - ETA: 0s - loss: 1.6316e-04 - mean_absolute_error: 0.0105
# Epoch 00312: val_loss did not improve from 0.00007
# 33/33 [==============================] - 3s 81ms/step - loss: 1.6316e-04 - mean_absolute_error: 0.0105 - val_loss: 1.0450e-04 - val_mean_absolute_error: 0.0092
# Epoch 313/400
# 33/33 [==============================] - ETA: 0s - loss: 1.4294e-04 - mean_absolute_error: 0.0101
# Epoch 00313: val_loss did not improve from 0.00007
# 33/33 [==============================] - 3s 90ms/step - loss: 1.4294e-04 - mean_absolute_error: 0.0101 - val_loss: 9.1242e-05 - val_mean_absolute_error: 0.0083
# Epoch 314/400
# 33/33 [==============================] - ETA: 0s - loss: 1.6643e-04 - mean_absolute_error: 0.0100
# Epoch 00314: val_loss did not improve from 0.00007
# 33/33 [==============================] - 3s 103ms/step - loss: 1.6643e-04 - mean_absolute_error: 0.0100 - val_loss: 1.1867e-04 - val_mean_absolute_error: 0.0091
# Epoch 315/400
# 33/33 [==============================] - ETA: 0s - loss: 1.6309e-04 - mean_absolute_error: 0.0105
# Epoch 00315: val_loss did not improve from 0.00007
# 33/33 [==============================] - 4s 108ms/step - loss: 1.6309e-04 - mean_absolute_error: 0.0105 - val_loss: 1.0817e-04 - val_mean_absolute_error: 0.0079
# Epoch 316/400
# 33/33 [==============================] - ETA: 0s - loss: 1.4301e-04 - mean_absolute_error: 0.0094
# Epoch 00316: val_loss did not improve from 0.00007
# 33/33 [==============================] - 3s 101ms/step - loss: 1.4301e-04 - mean_absolute_error: 0.0094 - val_loss: 1.2205e-04 - val_mean_absolute_error: 0.0095
# Epoch 317/400
# 33/33 [==============================] - ETA: 0s - loss: 1.3608e-04 - mean_absolute_error: 0.0101
# Epoch 00317: val_loss did not improve from 0.00007
# 33/33 [==============================] - 3s 105ms/step - loss: 1.3608e-04 - mean_absolute_error: 0.0101 - val_loss: 8.3564e-05 - val_mean_absolute_error: 0.0082
# Epoch 318/400
# 33/33 [==============================] - ETA: 0s - loss: 1.4182e-04 - mean_absolute_error: 0.0099
# Epoch 00318: val_loss did not improve from 0.00007
# 33/33 [==============================] - 3s 100ms/step - loss: 1.4182e-04 - mean_absolute_error: 0.0099 - val_loss: 9.9517e-05 - val_mean_absolute_error: 0.0078
# Epoch 319/400
# 33/33 [==============================] - ETA: 0s - loss: 1.4380e-04 - mean_absolute_error: 0.0100
# Epoch 00319: val_loss did not improve from 0.00007
# 33/33 [==============================] - 3s 104ms/step - loss: 1.4380e-04 - mean_absolute_error: 0.0100 - val_loss: 1.6859e-04 - val_mean_absolute_error: 0.0098
# Epoch 320/400
# 33/33 [==============================] - ETA: 0s - loss: 3.2257e-04 - mean_absolute_error: 0.0121
# Epoch 00320: val_loss did not improve from 0.00007
# 33/33 [==============================] - 3s 104ms/step - loss: 3.2257e-04 - mean_absolute_error: 0.0121 - val_loss: 1.6929e-04 - val_mean_absolute_error: 0.0114
# Epoch 321/400
# 33/33 [==============================] - ETA: 0s - loss: 2.0806e-04 - mean_absolute_error: 0.0115
# Epoch 00321: val_loss did not improve from 0.00007
# 33/33 [==============================] - 3s 93ms/step - loss: 2.0806e-04 - mean_absolute_error: 0.0115 - val_loss: 1.7254e-04 - val_mean_absolute_error: 0.0103
# Epoch 322/400
# 33/33 [==============================] - ETA: 0s - loss: 2.5963e-04 - mean_absolute_error: 0.0118
# Epoch 00322: val_loss did not improve from 0.00007
# 33/33 [==============================] - 3s 106ms/step - loss: 2.5963e-04 - mean_absolute_error: 0.0118 - val_loss: 1.5741e-04 - val_mean_absolute_error: 0.0096
# Epoch 323/400
# 33/33 [==============================] - ETA: 0s - loss: 2.3162e-04 - mean_absolute_error: 0.0111
# Epoch 00323: val_loss did not improve from 0.00007
# 33/33 [==============================] - 3s 103ms/step - loss: 2.3162e-04 - mean_absolute_error: 0.0111 - val_loss: 1.3297e-04 - val_mean_absolute_error: 0.0091
# Epoch 324/400
# 33/33 [==============================] - ETA: 0s - loss: 1.2723e-04 - mean_absolute_error: 0.0097
# Epoch 00324: val_loss did not improve from 0.00007
# 33/33 [==============================] - 3s 101ms/step - loss: 1.2723e-04 - mean_absolute_error: 0.0097 - val_loss: 1.4911e-04 - val_mean_absolute_error: 0.0083
# Epoch 325/400
# 33/33 [==============================] - ETA: 0s - loss: 1.8976e-04 - mean_absolute_error: 0.0105
# Epoch 00325: val_loss did not improve from 0.00007
# 33/33 [==============================] - 3s 106ms/step - loss: 1.8976e-04 - mean_absolute_error: 0.0105 - val_loss: 1.2401e-04 - val_mean_absolute_error: 0.0095
# Epoch 326/400
# 33/33 [==============================] - ETA: 0s - loss: 1.4140e-04 - mean_absolute_error: 0.0102
# Epoch 00326: val_loss did not improve from 0.00007
# 33/33 [==============================] - 3s 103ms/step - loss: 1.4140e-04 - mean_absolute_error: 0.0102 - val_loss: 1.7068e-04 - val_mean_absolute_error: 0.0112
# Epoch 327/400
# 33/33 [==============================] - ETA: 0s - loss: 1.5131e-04 - mean_absolute_error: 0.0106
# Epoch 00327: val_loss did not improve from 0.00007
# 33/33 [==============================] - 3s 100ms/step - loss: 1.5131e-04 - mean_absolute_error: 0.0106 - val_loss: 9.3851e-05 - val_mean_absolute_error: 0.0075
# Epoch 328/400
# 33/33 [==============================] - ETA: 0s - loss: 2.1146e-04 - mean_absolute_error: 0.0112
# Epoch 00328: val_loss did not improve from 0.00007
# 33/33 [==============================] - 3s 101ms/step - loss: 2.1146e-04 - mean_absolute_error: 0.0112 - val_loss: 1.6178e-04 - val_mean_absolute_error: 0.0096
# Epoch 329/400
# 33/33 [==============================] - ETA: 0s - loss: 1.5892e-04 - mean_absolute_error: 0.0101
# Epoch 00329: val_loss did not improve from 0.00007
# 33/33 [==============================] - 3s 102ms/step - loss: 1.5892e-04 - mean_absolute_error: 0.0101 - val_loss: 1.1723e-04 - val_mean_absolute_error: 0.0081
# Epoch 330/400
# 33/33 [==============================] - ETA: 0s - loss: 1.3747e-04 - mean_absolute_error: 0.0096
# Epoch 00330: val_loss did not improve from 0.00007
# 33/33 [==============================] - 3s 101ms/step - loss: 1.3747e-04 - mean_absolute_error: 0.0096 - val_loss: 1.2550e-04 - val_mean_absolute_error: 0.0083
# Epoch 331/400
# 33/33 [==============================] - ETA: 0s - loss: 1.5618e-04 - mean_absolute_error: 0.0105
# Epoch 00331: val_loss did not improve from 0.00007
# 33/33 [==============================] - 3s 102ms/step - loss: 1.5618e-04 - mean_absolute_error: 0.0105 - val_loss: 1.0800e-04 - val_mean_absolute_error: 0.0089
# Epoch 332/400
# 33/33 [==============================] - ETA: 0s - loss: 1.3201e-04 - mean_absolute_error: 0.0097
# Epoch 00332: val_loss did not improve from 0.00007
# 33/33 [==============================] - 3s 101ms/step - loss: 1.3201e-04 - mean_absolute_error: 0.0097 - val_loss: 8.9912e-05 - val_mean_absolute_error: 0.0082
# Epoch 333/400
# 33/33 [==============================] - ETA: 0s - loss: 1.2847e-04 - mean_absolute_error: 0.0097
# Epoch 00333: val_loss did not improve from 0.00007
# 33/33 [==============================] - 3s 105ms/step - loss: 1.2847e-04 - mean_absolute_error: 0.0097 - val_loss: 1.0565e-04 - val_mean_absolute_error: 0.0091
# Epoch 334/400
# 33/33 [==============================] - ETA: 0s - loss: 1.2612e-04 - mean_absolute_error: 0.0096
# Epoch 00334: val_loss did not improve from 0.00007
# 33/33 [==============================] - 3s 103ms/step - loss: 1.2612e-04 - mean_absolute_error: 0.0096 - val_loss: 7.8248e-05 - val_mean_absolute_error: 0.0074
# Epoch 335/400
# 33/33 [==============================] - ETA: 0s - loss: 1.5336e-04 - mean_absolute_error: 0.0099
# Epoch 00335: val_loss did not improve from 0.00007
# 33/33 [==============================] - 3s 103ms/step - loss: 1.5336e-04 - mean_absolute_error: 0.0099 - val_loss: 1.1526e-04 - val_mean_absolute_error: 0.0092
# Epoch 336/400
# 33/33 [==============================] - ETA: 0s - loss: 1.3880e-04 - mean_absolute_error: 0.0096
# Epoch 00336: val_loss did not improve from 0.00007
# 33/33 [==============================] - 3s 102ms/step - loss: 1.3880e-04 - mean_absolute_error: 0.0096 - val_loss: 9.7144e-05 - val_mean_absolute_error: 0.0077
# Epoch 337/400
# 33/33 [==============================] - ETA: 0s - loss: 1.3176e-04 - mean_absolute_error: 0.0097
# Epoch 00337: val_loss did not improve from 0.00007
# 33/33 [==============================] - 3s 102ms/step - loss: 1.3176e-04 - mean_absolute_error: 0.0097 - val_loss: 1.0031e-04 - val_mean_absolute_error: 0.0094
# Epoch 338/400
# 33/33 [==============================] - ETA: 0s - loss: 1.9691e-04 - mean_absolute_error: 0.0112
# Epoch 00338: val_loss did not improve from 0.00007
# 33/33 [==============================] - 3s 103ms/step - loss: 1.9691e-04 - mean_absolute_error: 0.0112 - val_loss: 1.1888e-04 - val_mean_absolute_error: 0.0090
# Epoch 339/400
# 33/33 [==============================] - ETA: 0s - loss: 2.0905e-04 - mean_absolute_error: 0.0108
# Epoch 00339: val_loss did not improve from 0.00007
# 33/33 [==============================] - 3s 103ms/step - loss: 2.0905e-04 - mean_absolute_error: 0.0108 - val_loss: 1.1422e-04 - val_mean_absolute_error: 0.0091
# Epoch 340/400
# 33/33 [==============================] - ETA: 0s - loss: 1.7484e-04 - mean_absolute_error: 0.0106
# Epoch 00340: val_loss did not improve from 0.00007
# 33/33 [==============================] - 3s 101ms/step - loss: 1.7484e-04 - mean_absolute_error: 0.0106 - val_loss: 1.0152e-04 - val_mean_absolute_error: 0.0094
# Epoch 341/400
# 33/33 [==============================] - ETA: 0s - loss: 2.2446e-04 - mean_absolute_error: 0.0119
# Epoch 00341: val_loss did not improve from 0.00007
# 33/33 [==============================] - 3s 101ms/step - loss: 2.2446e-04 - mean_absolute_error: 0.0119 - val_loss: 1.8432e-04 - val_mean_absolute_error: 0.0140
# Epoch 342/400
# 33/33 [==============================] - ETA: 0s - loss: 1.9543e-04 - mean_absolute_error: 0.0119
# Epoch 00342: val_loss did not improve from 0.00007
# 33/33 [==============================] - 3s 104ms/step - loss: 1.9543e-04 - mean_absolute_error: 0.0119 - val_loss: 1.1991e-04 - val_mean_absolute_error: 0.0094
# Epoch 343/400
# 33/33 [==============================] - ETA: 0s - loss: 1.5490e-04 - mean_absolute_error: 0.0103
# Epoch 00343: val_loss did not improve from 0.00007
# 33/33 [==============================] - 3s 104ms/step - loss: 1.5490e-04 - mean_absolute_error: 0.0103 - val_loss: 1.0249e-04 - val_mean_absolute_error: 0.0100
# Epoch 344/400
# 33/33 [==============================] - ETA: 0s - loss: 1.6856e-04 - mean_absolute_error: 0.0106
# Epoch 00344: val_loss did not improve from 0.00007
# 33/33 [==============================] - 3s 104ms/step - loss: 1.6856e-04 - mean_absolute_error: 0.0106 - val_loss: 9.5670e-05 - val_mean_absolute_error: 0.0084
# Epoch 345/400
# 33/33 [==============================] - ETA: 0s - loss: 1.4569e-04 - mean_absolute_error: 0.0100
# Epoch 00345: val_loss did not improve from 0.00007
# 33/33 [==============================] - 3s 102ms/step - loss: 1.4569e-04 - mean_absolute_error: 0.0100 - val_loss: 8.3020e-05 - val_mean_absolute_error: 0.0073
# Epoch 346/400
# 33/33 [==============================] - ETA: 0s - loss: 1.2868e-04 - mean_absolute_error: 0.0092
# Epoch 00346: val_loss did not improve from 0.00007
# 33/33 [==============================] - 3s 104ms/step - loss: 1.2868e-04 - mean_absolute_error: 0.0092 - val_loss: 9.1873e-05 - val_mean_absolute_error: 0.0080
# Epoch 347/400
# 33/33 [==============================] - ETA: 0s - loss: 1.2291e-04 - mean_absolute_error: 0.0099
# Epoch 00347: val_loss did not improve from 0.00007
# 33/33 [==============================] - 3s 103ms/step - loss: 1.2291e-04 - mean_absolute_error: 0.0099 - val_loss: 9.7829e-05 - val_mean_absolute_error: 0.0084
# Epoch 348/400
# 33/33 [==============================] - ETA: 0s - loss: 2.0088e-04 - mean_absolute_error: 0.0109
# Epoch 00348: val_loss did not improve from 0.00007
# 33/33 [==============================] - 3s 102ms/step - loss: 2.0088e-04 - mean_absolute_error: 0.0109 - val_loss: 1.2156e-04 - val_mean_absolute_error: 0.0083
# Epoch 349/400
# 33/33 [==============================] - ETA: 0s - loss: 1.2489e-04 - mean_absolute_error: 0.0096
# Epoch 00349: val_loss did not improve from 0.00007
# 33/33 [==============================] - 3s 103ms/step - loss: 1.2489e-04 - mean_absolute_error: 0.0096 - val_loss: 1.3945e-04 - val_mean_absolute_error: 0.0094
# Epoch 350/400
# 33/33 [==============================] - ETA: 0s - loss: 1.8395e-04 - mean_absolute_error: 0.0105
# Epoch 00350: val_loss did not improve from 0.00007
# 33/33 [==============================] - 3s 103ms/step - loss: 1.8395e-04 - mean_absolute_error: 0.0105 - val_loss: 2.4329e-04 - val_mean_absolute_error: 0.0121
# Epoch 351/400
# 33/33 [==============================] - ETA: 0s - loss: 1.5579e-04 - mean_absolute_error: 0.0106
# Epoch 00351: val_loss did not improve from 0.00007
# 33/33 [==============================] - 3s 102ms/step - loss: 1.5579e-04 - mean_absolute_error: 0.0106 - val_loss: 9.7453e-05 - val_mean_absolute_error: 0.0078
# Epoch 352/400
# 33/33 [==============================] - ETA: 0s - loss: 1.5716e-04 - mean_absolute_error: 0.0103
# Epoch 00352: val_loss did not improve from 0.00007
# 33/33 [==============================] - 3s 103ms/step - loss: 1.5716e-04 - mean_absolute_error: 0.0103 - val_loss: 1.2615e-04 - val_mean_absolute_error: 0.0093
# Epoch 353/400
# 33/33 [==============================] - ETA: 0s - loss: 1.9924e-04 - mean_absolute_error: 0.0111
# Epoch 00353: val_loss did not improve from 0.00007
# 33/33 [==============================] - 3s 103ms/step - loss: 1.9924e-04 - mean_absolute_error: 0.0111 - val_loss: 1.0960e-04 - val_mean_absolute_error: 0.0081
# Epoch 354/400
# 33/33 [==============================] - ETA: 0s - loss: 1.6942e-04 - mean_absolute_error: 0.0104
# Epoch 00354: val_loss did not improve from 0.00007
# 33/33 [==============================] - 3s 103ms/step - loss: 1.6942e-04 - mean_absolute_error: 0.0104 - val_loss: 1.1139e-04 - val_mean_absolute_error: 0.0079
# Epoch 355/400
# 33/33 [==============================] - ETA: 0s - loss: 1.5250e-04 - mean_absolute_error: 0.0097
# Epoch 00355: val_loss did not improve from 0.00007
# 33/33 [==============================] - 3s 104ms/step - loss: 1.5250e-04 - mean_absolute_error: 0.0097 - val_loss: 1.5809e-04 - val_mean_absolute_error: 0.0098
# Epoch 356/400
# 33/33 [==============================] - ETA: 0s - loss: 1.3340e-04 - mean_absolute_error: 0.0100
# Epoch 00356: val_loss did not improve from 0.00007
# 33/33 [==============================] - 3s 103ms/step - loss: 1.3340e-04 - mean_absolute_error: 0.0100 - val_loss: 7.7915e-05 - val_mean_absolute_error: 0.0076
# Epoch 357/400
# 33/33 [==============================] - ETA: 0s - loss: 1.8716e-04 - mean_absolute_error: 0.0109
# Epoch 00357: val_loss did not improve from 0.00007
# 33/33 [==============================] - 3s 104ms/step - loss: 1.8716e-04 - mean_absolute_error: 0.0109 - val_loss: 1.3177e-04 - val_mean_absolute_error: 0.0081
# Epoch 358/400
# 33/33 [==============================] - ETA: 0s - loss: 1.2762e-04 - mean_absolute_error: 0.0098
# Epoch 00358: val_loss did not improve from 0.00007
# 33/33 [==============================] - 4s 107ms/step - loss: 1.2762e-04 - mean_absolute_error: 0.0098 - val_loss: 9.1515e-05 - val_mean_absolute_error: 0.0078
# Epoch 359/400
# 33/33 [==============================] - ETA: 0s - loss: 1.5640e-04 - mean_absolute_error: 0.0110
# Epoch 00359: val_loss did not improve from 0.00007
# 33/33 [==============================] - 3s 104ms/step - loss: 1.5640e-04 - mean_absolute_error: 0.0110 - val_loss: 1.5419e-04 - val_mean_absolute_error: 0.0105
# Epoch 00359: early stopping

# %%
data = load_data(ticker, N_STEPS, lookup_step=LOOKUP_STEP, test_size=TEST_SIZE,
                feature_columns=FEATURE_COLUMNS, shuffle=False)
# construct the model
# model = create_model(N_STEPS, loss=LOSS, units=UNITS, cell=CELL, n_layers=N_LAYERS,
#                     dropout=DROPOUT, optimizer=OPTIMIZER, bidirectional=BIDIRECTIONAL)
model_path = os.path.join("results", model_name) + ".h5"
# model.load_weights(model_path)

# %%
# evaluate the model
mse, mae = model.evaluate(data["X_test"], data["y_test"], verbose=0)
# calculate the mean absolute error (inverse scaling)
mean_absolute_error = data["column_scaler"]["adjclose"].inverse_transform([[mae]])[0][0]
print("Mean Absolute Error:", mean_absolute_error)
# Out:
# Mean Absolute Error: 15.856781384079646

# %%
def predict(model, data):
    # retrieve the last sequence from data
    last_sequence = data["last_sequence"][-N_STEPS:]
    # retrieve the column scalers
    column_scaler = data["column_scaler"]
    # reshape the last sequence
    last_sequence = last_sequence.reshape((last_sequence.shape[1], last_sequence.shape[0]))
    # expand dimension
    last_sequence = np.expand_dims(last_sequence, axis=0)
    # get the prediction (scaled from 0 to 1)
    prediction = model.predict(last_sequence)
    # get the price (by inverting the scaling)
    predicted_price = column_scaler["adjclose"].inverse_transform(prediction)[0][0]
    return predicted_price

# %%
# predict the future price
future_price = predict(model, data)
print(f"The price in {LOOKUP_STEP} days will be ${future_price:.2f}.")
# Out:
# The price in 10 days will be $416.62.

# %%
def plot_graph(model, data):
    y_test = data["y_test"]
    X_test = data["X_test"]
    y_pred = model.predict(X_test)
    y_test = np.squeeze(data["column_scaler"]["adjclose"].inverse_transform(np.expand_dims(y_test, axis=0)))
    y_pred = np.squeeze(data["column_scaler"]["adjclose"].inverse_transform(y_pred))
    # last 200 days, feel free to edit that
    plt.plot(y_test[-200:], c='b')
    plt.plot(y_pred[-200:], c='r')
    plt.xlabel("Days")
    plt.ylabel("Price")
    plt.legend(["Actual Price", "Predicted Price"])
    plt.show()

# %%
plt.figure(figsize=(10, 6))

plot_graph(model, data)

# %%
def get_accuracy(model, data):
    y_test = data["y_test"]
    X_test = data["X_test"]
    y_pred = model.predict(X_test)
    y_test = np.squeeze(data["column_scaler"]["adjclose"].inverse_transform(np.expand_dims(y_test, axis=0)))
    y_pred = np.squeeze(data["column_scaler"]["adjclose"].inverse_transform(y_pred))
    print(y_test)
    y_pred = list(map(lambda current, future: int(float(future) > float(current)), y_test[:-LOOKUP_STEP], y_pred[LOOKUP_STEP:]))
    y_test = list(map(lambda current, future: int(float(future) > float(current)), y_test[:-LOOKUP_STEP], y_test[LOOKUP_STEP:]))
    return accuracy_score(y_test, y_pred)

# %%
print(str(LOOKUP_STEP) + ":", "Accuracy Score:", get_accuracy(model, data))
# Out:
# 10: Accuracy Score: 0.6627450980392157
