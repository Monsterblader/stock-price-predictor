# %% [markdown]
# https://www.thepythoncode.com/article/stock-price-prediction-in-python-using-tensorflow-2-and-keras
#
# https://code.tutsplus.com/tutorials/building-a-multi-line-chart-using-d3js--cms-22935

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, Bidirectional
from tensorflow.keras.callbacks import ModelCheckpoint, TensorBoard, EarlyStopping
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from yahoo_fin import stock_info as si
from collections import deque

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import time
import os
import random

# %%
# set seed, so we can get the same results after rerunning several times
np.random.seed(314)
tf.random.set_seed(314)
random.seed(314)

# %%
def load_data(ticker, n_steps=50, scale=True, shuffle=True, lookup_step=1, 
                test_size=0.2, feature_columns=['adjclose', 'volume', 'open', 'high', 'low']):
    """
    Loads data from Yahoo Finance source, as well as scaling, shuffling, normalizing and splitting.
    Params:
        ticker (str/pd.DataFrame): the ticker you want to load, examples include AAPL, TESL, etc.
        n_steps (int): the historical sequence length (i.e window size) used to predict, default is 50
        scale (bool): whether to scale prices from 0 to 1, default is True
        shuffle (bool): whether to shuffle the data, default is True
        lookup_step (int): the future lookup step to predict, default is 1 (e.g next day)
        test_size (float): ratio for test data, default is 0.2 (20% testing data)
        feature_columns (list): the list of features to use to feed into the model, default is everything grabbed from yahoo_fin
    """
    # see if ticker is already a loaded stock from yahoo finance
    if isinstance(ticker, str):
        # load it from yahoo_fin library
        df = si.get_data(ticker)
    elif isinstance(ticker, pd.DataFrame):
        # already loaded, use it directly
        df = ticker
    else:
        raise TypeError("ticker can be either a str or a `pd.DataFrame` instances")
    # this will contain all the elements we want to return from this function
    result = {}
    # we will also return the original dataframe itself
    result['df'] = df.copy()
    # make sure that the passed feature_columns exist in the dataframe
    for col in feature_columns:
        assert col in df.columns, f"'{col}' does not exist in the dataframe."
    if scale:
        column_scaler = {}
        # scale the data (prices) from 0 to 1
        for column in feature_columns:
            scaler = preprocessing.MinMaxScaler()
            df[column] = scaler.fit_transform(np.expand_dims(df[column].values, axis=1))
            column_scaler[column] = scaler
        # add the MinMaxScaler instances to the result returned
        result["column_scaler"] = column_scaler
    # add the target column (label) by shifting by `lookup_step`
    df['future'] = df['adjclose'].shift(-lookup_step)
    # last `lookup_step` columns contains NaN in future column
    # get them before droping NaNs
    last_sequence = np.array(df[feature_columns].tail(lookup_step))
    # drop NaNs
    df.dropna(inplace=True)
    sequence_data = []
    sequences = deque(maxlen=n_steps)
    for entry, target in zip(df[feature_columns].values, df['future'].values):
        sequences.append(entry)
        if len(sequences) == n_steps:
            sequence_data.append([np.array(sequences), target])
    # get the last sequence by appending the last `n_step` sequence with `lookup_step` sequence
    # for instance, if n_steps=50 and lookup_step=10, last_sequence should be of 60 (that is 50+10) length
    # this last_sequence will be used to predict future stock prices not available in the dataset
    last_sequence = list(sequences) + list(last_sequence)
    last_sequence = np.array(last_sequence)
    # add to result
    result['last_sequence'] = last_sequence
    # construct the X's and y's
    X, y = [], []
    for seq, target in sequence_data:
        X.append(seq)
        y.append(target)
    # convert to numpy arrays
    X = np.array(X)
    y = np.array(y)
    # reshape X to fit the neural network
    X = X.reshape((X.shape[0], X.shape[2], X.shape[1]))
    # split the dataset
    result["X_train"], result["X_test"], result["y_train"], result["y_test"] = train_test_split(X, y, 
                                                                               test_size=test_size, shuffle=shuffle)
    # split_point = int(len(X) * (1 - test_size))
    # result["X_train"], result["X_test"], result["y_train"], result["y_test"] = X[:split_point], X[split_point:], y[:split_point], y[split_point:]
    # return the result
    return result

# %%
def create_model(sequence_length, units=256, cell=LSTM, n_layers=2, dropout=0.3,
                loss="mean_absolute_error", optimizer="rmsprop", bidirectional=False):
    model = Sequential()
    for i in range(n_layers):
        if i == 0:
            # first layer
            if bidirectional:
                model.add(Bidirectional(cell(units, return_sequences=True), input_shape=(None, sequence_length)))
            else:
                model.add(cell(units, return_sequences=True, input_shape=(None, sequence_length)))
        elif i == n_layers - 1:
            # last layer
            if bidirectional:
                model.add(Bidirectional(cell(units, return_sequences=False)))
            else:
                model.add(cell(units, return_sequences=False))
        else:
            # hidden layers
            if bidirectional:
                model.add(Bidirectional(cell(units, return_sequences=True)))
            else:
                model.add(cell(units, return_sequences=True))
        # add dropout after each layer
        model.add(Dropout(dropout))
    model.add(Dense(1, activation="linear"))
    model.compile(loss=loss, metrics=["mean_absolute_error"], optimizer=optimizer)
    return model

# %%
# Window size or the sequence length
N_STEPS = 20
# Lookup step, 1 is the next day
LOOKUP_STEP = 10
# test ratio size, 0.2 is 20%
TEST_SIZE = 0.2
# features to use
FEATURE_COLUMNS = ["adjclose", "volume", "open", "high", "low"]
# date now
date_now = time.strftime("%Y-%m-%d")
### model parameters
N_LAYERS = 3
# LSTM cell
CELL = LSTM
# 256 LSTM neurons
UNITS = 256
# 40% dropout
DROPOUT = 0.4
# whether to use bidirectional RNNs
BIDIRECTIONAL = True
### training parameters
# mean absolute error loss
# LOSS = "mae"
# huber loss
LOSS = "huber_loss"
OPTIMIZER = "adam"
BATCH_SIZE = 64
EPOCHS = 400
# Tesla stock market
ticker = "TSLA"
ticker_data_filename = os.path.join("data", f"{ticker}_{date_now}.csv")
# model name to save, making it as unique as possible based on parameters
model_name = f"{date_now}_{ticker}-{LOSS}-{OPTIMIZER}-{CELL.__name__}-seq-{N_STEPS}-step-{LOOKUP_STEP}-layers-{N_LAYERS}-units-{UNITS}"
if BIDIRECTIONAL:
    model_name += "-b"

# %%
# create these folders if they does not exist
if not os.path.isdir("results"):
    os.mkdir("results")
if not os.path.isdir("logs"):
    os.mkdir("logs")
if not os.path.isdir("data"):
    os.mkdir("data")

# %%
# load the data
data = load_data(ticker, N_STEPS, lookup_step=LOOKUP_STEP, test_size=TEST_SIZE, feature_columns=FEATURE_COLUMNS)
# save the dataframe
data["df"].to_csv(ticker_data_filename)
# construct the model
model = create_model(N_STEPS, loss=LOSS, units=UNITS, cell=CELL, n_layers=N_LAYERS,
                    dropout=DROPOUT, optimizer=OPTIMIZER, bidirectional=BIDIRECTIONAL)
# some tensorflow callbacks
checkpointer = ModelCheckpoint(os.path.join("results", model_name + ".h5"), save_weights_only=True, save_best_only=True, verbose=1)
tensorboard = TensorBoard(log_dir=os.path.join("logs", model_name))
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=50)

history = model.fit(data["X_train"], data["y_train"],
                    batch_size=BATCH_SIZE,
                    epochs=EPOCHS,
                    validation_data=(data["X_test"], data["y_test"]),
                    callbacks=[checkpointer, tensorboard, es],
                    verbose=1)
model.save(os.path.join("results", model_name) + ".h5")
# Out:
# 457e-04 - mean_absolute_error: 0.0104 - val_loss: 9.5887e-05 - val_mean_absolute_error: 0.0078
# Epoch 341/400
# 33/33 [==============================] - ETA: 0s - loss: 1.7163e-04 - mean_absolute_error: 0.0107
# Epoch 00341: val_loss did not improve from 0.00008
# 33/33 [==============================] - 3s 91ms/step - loss: 1.7163e-04 - mean_absolute_error: 0.0107 - val_loss: 8.7715e-05 - val_mean_absolute_error: 0.0077
# Epoch 342/400
# 33/33 [==============================] - ETA: 0s - loss: 1.4050e-04 - mean_absolute_error: 0.0100
# Epoch 00342: val_loss did not improve from 0.00008
# 33/33 [==============================] - 3s 92ms/step - loss: 1.4050e-04 - mean_absolute_error: 0.0100 - val_loss: 9.7009e-05 - val_mean_absolute_error: 0.0088
# Epoch 343/400
# 33/33 [==============================] - ETA: 0s - loss: 1.5206e-04 - mean_absolute_error: 0.0101
# Epoch 00343: val_loss did not improve from 0.00008
# 33/33 [==============================] - 3s 91ms/step - loss: 1.5206e-04 - mean_absolute_error: 0.0101 - val_loss: 7.7234e-05 - val_mean_absolute_error: 0.0076
# Epoch 344/400
# 33/33 [==============================] - ETA: 0s - loss: 1.6694e-04 - mean_absolute_error: 0.0102
# Epoch 00344: val_loss did not improve from 0.00008
# 33/33 [==============================] - 3s 92ms/step - loss: 1.6694e-04 - mean_absolute_error: 0.0102 - val_loss: 1.1111e-04 - val_mean_absolute_error: 0.0100
# Epoch 345/400
# 33/33 [==============================] - ETA: 0s - loss: 1.7868e-04 - mean_absolute_error: 0.0103
# Epoch 00345: val_loss did not improve from 0.00008
# 33/33 [==============================] - 3s 91ms/step - loss: 1.7868e-04 - mean_absolute_error: 0.0103 - val_loss: 1.5325e-04 - val_mean_absolute_error: 0.0093
# Epoch 346/400
# 33/33 [==============================] - ETA: 0s - loss: 1.6070e-04 - mean_absolute_error: 0.0103
# Epoch 00346: val_loss did not improve from 0.00008
# 33/33 [==============================] - 3s 91ms/step - loss: 1.6070e-04 - mean_absolute_error: 0.0103 - val_loss: 1.2848e-04 - val_mean_absolute_error: 0.0105
# Epoch 347/400
# 33/33 [==============================] - ETA: 0s - loss: 1.2110e-04 - mean_absolute_error: 0.0096
# Epoch 00347: val_loss did not improve from 0.00008
# 33/33 [==============================] - 3s 92ms/step - loss: 1.2110e-04 - mean_absolute_error: 0.0096 - val_loss: 7.8342e-05 - val_mean_absolute_error: 0.0072
# Epoch 348/400
# 33/33 [==============================] - ETA: 0s - loss: 1.4644e-04 - mean_absolute_error: 0.0098
# Epoch 00348: val_loss improved from 0.00008 to 0.00007, saving model to results/2020-12-02_TSLA-huber_loss-adam-LSTM-seq-20-step-10-layers-3-units-256-b.h5
# 33/33 [==============================] - 3s 91ms/step - loss: 1.4644e-04 - mean_absolute_error: 0.0098 - val_loss: 6.9160e-05 - val_mean_absolute_error: 0.0071
# Epoch 349/400
# 33/33 [==============================] - ETA: 0s - loss: 1.2638e-04 - mean_absolute_error: 0.0097
# Epoch 00349: val_loss did not improve from 0.00007
# 33/33 [==============================] - 3s 92ms/step - loss: 1.2638e-04 - mean_absolute_error: 0.0097 - val_loss: 8.1355e-05 - val_mean_absolute_error: 0.0079
# Epoch 350/400
# 33/33 [==============================] - ETA: 0s - loss: 1.2909e-04 - mean_absolute_error: 0.0093
# Epoch 00350: val_loss did not improve from 0.00007
# 33/33 [==============================] - 3s 92ms/step - loss: 1.2909e-04 - mean_absolute_error: 0.0093 - val_loss: 9.6484e-05 - val_mean_absolute_error: 0.0080
# Epoch 351/400
# 33/33 [==============================] - ETA: 0s - loss: 1.4946e-04 - mean_absolute_error: 0.0106
# Epoch 00351: val_loss did not improve from 0.00007
# 33/33 [==============================] - 3s 91ms/step - loss: 1.4946e-04 - mean_absolute_error: 0.0106 - val_loss: 9.7364e-05 - val_mean_absolute_error: 0.0077
# Epoch 352/400
# 33/33 [==============================] - ETA: 0s - loss: 1.3539e-04 - mean_absolute_error: 0.0096
# Epoch 00352: val_loss did not improve from 0.00007
# 33/33 [==============================] - 3s 91ms/step - loss: 1.3539e-04 - mean_absolute_error: 0.0096 - val_loss: 7.8073e-05 - val_mean_absolute_error: 0.0077
# Epoch 353/400
# 33/33 [==============================] - ETA: 0s - loss: 1.6608e-04 - mean_absolute_error: 0.0101
# Epoch 00353: val_loss did not improve from 0.00007
# 33/33 [==============================] - 3s 90ms/step - loss: 1.6608e-04 - mean_absolute_error: 0.0101 - val_loss: 8.3830e-05 - val_mean_absolute_error: 0.0076
# Epoch 354/400
# 33/33 [==============================] - ETA: 0s - loss: 1.3889e-04 - mean_absolute_error: 0.0099
# Epoch 00354: val_loss did not improve from 0.00007
# 33/33 [==============================] - 3s 92ms/step - loss: 1.3889e-04 - mean_absolute_error: 0.0099 - val_loss: 7.6496e-05 - val_mean_absolute_error: 0.0081
# Epoch 355/400
# 33/33 [==============================] - ETA: 0s - loss: 1.4095e-04 - mean_absolute_error: 0.0099
# Epoch 00355: val_loss did not improve from 0.00007
# 33/33 [==============================] - 3s 91ms/step - loss: 1.4095e-04 - mean_absolute_error: 0.0099 - val_loss: 9.7358e-05 - val_mean_absolute_error: 0.0074
# Epoch 356/400
# 33/33 [==============================] - ETA: 0s - loss: 1.5556e-04 - mean_absolute_error: 0.0103
# Epoch 00356: val_loss did not improve from 0.00007
# 33/33 [==============================] - 3s 91ms/step - loss: 1.5556e-04 - mean_absolute_error: 0.0103 - val_loss: 9.1838e-05 - val_mean_absolute_error: 0.0092
# Epoch 357/400
# 33/33 [==============================] - ETA: 0s - loss: 1.3964e-04 - mean_absolute_error: 0.0099
# Epoch 00357: val_loss did not improve from 0.00007
# 33/33 [==============================] - 3s 91ms/step - loss: 1.3964e-04 - mean_absolute_error: 0.0099 - val_loss: 8.0832e-05 - val_mean_absolute_error: 0.0091
# Epoch 358/400
# 33/33 [==============================] - ETA: 0s - loss: 1.3438e-04 - mean_absolute_error: 0.0099
# Epoch 00358: val_loss did not improve from 0.00007
# 33/33 [==============================] - 3s 92ms/step - loss: 1.3438e-04 - mean_absolute_error: 0.0099 - val_loss: 9.3014e-05 - val_mean_absolute_error: 0.0088
# Epoch 359/400
# 33/33 [==============================] - ETA: 0s - loss: 1.1519e-04 - mean_absolute_error: 0.0093
# Epoch 00359: val_loss did not improve from 0.00007
# 33/33 [==============================] - 3s 93ms/step - loss: 1.1519e-04 - mean_absolute_error: 0.0093 - val_loss: 9.2401e-05 - val_mean_absolute_error: 0.0078
# Epoch 360/400
# 33/33 [==============================] - ETA: 0s - loss: 1.2512e-04 - mean_absolute_error: 0.0094
# Epoch 00360: val_loss did not improve from 0.00007
# 33/33 [==============================] - 3s 92ms/step - loss: 1.2512e-04 - mean_absolute_error: 0.0094 - val_loss: 9.3794e-05 - val_mean_absolute_error: 0.0083
# Epoch 361/400
# 33/33 [==============================] - ETA: 0s - loss: 1.2877e-04 - mean_absolute_error: 0.0099
# Epoch 00361: val_loss did not improve from 0.00007
# 33/33 [==============================] - 3s 94ms/step - loss: 1.2877e-04 - mean_absolute_error: 0.0099 - val_loss: 1.1006e-04 - val_mean_absolute_error: 0.0091
# Epoch 362/400
# 33/33 [==============================] - ETA: 0s - loss: 1.3547e-04 - mean_absolute_error: 0.0101
# Epoch 00362: val_loss did not improve from 0.00007
# 33/33 [==============================] - 3s 92ms/step - loss: 1.3547e-04 - mean_absolute_error: 0.0101 - val_loss: 7.7245e-05 - val_mean_absolute_error: 0.0087
# Epoch 363/400
# 33/33 [==============================] - ETA: 0s - loss: 1.4508e-04 - mean_absolute_error: 0.0100
# Epoch 00363: val_loss did not improve from 0.00007
# 33/33 [==============================] - 3s 92ms/step - loss: 1.4508e-04 - mean_absolute_error: 0.0100 - val_loss: 1.0299e-04 - val_mean_absolute_error: 0.0080
# Epoch 364/400
# 33/33 [==============================] - ETA: 0s - loss: 1.2975e-04 - mean_absolute_error: 0.0093
# Epoch 00364: val_loss did not improve from 0.00007
# 33/33 [==============================] - 3s 92ms/step - loss: 1.2975e-04 - mean_absolute_error: 0.0093 - val_loss: 1.1181e-04 - val_mean_absolute_error: 0.0091
# Epoch 365/400
# 33/33 [==============================] - ETA: 0s - loss: 1.8048e-04 - mean_absolute_error: 0.0101
# Epoch 00365: val_loss did not improve from 0.00007
# 33/33 [==============================] - 3s 91ms/step - loss: 1.8048e-04 - mean_absolute_error: 0.0101 - val_loss: 8.6875e-05 - val_mean_absolute_error: 0.0077
# Epoch 366/400
# 33/33 [==============================] - ETA: 0s - loss: 1.6257e-04 - mean_absolute_error: 0.0107
# Epoch 00366: val_loss did not improve from 0.00007
# 33/33 [==============================] - 3s 91ms/step - loss: 1.6257e-04 - mean_absolute_error: 0.0107 - val_loss: 2.2494e-04 - val_mean_absolute_error: 0.0096
# Epoch 367/400
# 33/33 [==============================] - ETA: 0s - loss: 1.5000e-04 - mean_absolute_error: 0.0103
# Epoch 00367: val_loss did not improve from 0.00007
# 33/33 [==============================] - 3s 92ms/step - loss: 1.5000e-04 - mean_absolute_error: 0.0103 - val_loss: 8.2226e-05 - val_mean_absolute_error: 0.0075
# Epoch 368/400
# 33/33 [==============================] - ETA: 0s - loss: 1.0286e-04 - mean_absolute_error: 0.0090
# Epoch 00368: val_loss improved from 0.00007 to 0.00007, saving model to results/2020-12-02_TSLA-huber_loss-adam-LSTM-seq-20-step-10-layers-3-units-256-b.h5
# 33/33 [==============================] - 3s 92ms/step - loss: 1.0286e-04 - mean_absolute_error: 0.0090 - val_loss: 6.5507e-05 - val_mean_absolute_error: 0.0068
# Epoch 369/400
# 33/33 [==============================] - ETA: 0s - loss: 1.2453e-04 - mean_absolute_error: 0.0093
# Epoch 00369: val_loss did not improve from 0.00007
# 33/33 [==============================] - 3s 93ms/step - loss: 1.2453e-04 - mean_absolute_error: 0.0093 - val_loss: 9.0655e-05 - val_mean_absolute_error: 0.0078
# Epoch 370/400
# 33/33 [==============================] - ETA: 0s - loss: 1.2890e-04 - mean_absolute_error: 0.0095
# Epoch 00370: val_loss did not improve from 0.00007
# 33/33 [==============================] - 3s 90ms/step - loss: 1.2890e-04 - mean_absolute_error: 0.0095 - val_loss: 9.9462e-05 - val_mean_absolute_error: 0.0082
# Epoch 371/400
# 33/33 [==============================] - ETA: 0s - loss: 1.2603e-04 - mean_absolute_error: 0.0094
# Epoch 00371: val_loss did not improve from 0.00007
# 33/33 [==============================] - 3s 91ms/step - loss: 1.2603e-04 - mean_absolute_error: 0.0094 - val_loss: 7.5702e-05 - val_mean_absolute_error: 0.0075
# Epoch 372/400
# 33/33 [==============================] - ETA: 0s - loss: 1.3635e-04 - mean_absolute_error: 0.0095
# Epoch 00372: val_loss did not improve from 0.00007
# 33/33 [==============================] - 3s 91ms/step - loss: 1.3635e-04 - mean_absolute_error: 0.0095 - val_loss: 7.5651e-05 - val_mean_absolute_error: 0.0078
# Epoch 373/400
# 33/33 [==============================] - ETA: 0s - loss: 1.2323e-04 - mean_absolute_error: 0.0095
# Epoch 00373: val_loss did not improve from 0.00007
# 33/33 [==============================] - 3s 91ms/step - loss: 1.2323e-04 - mean_absolute_error: 0.0095 - val_loss: 1.2433e-04 - val_mean_absolute_error: 0.0082
# Epoch 374/400
# 33/33 [==============================] - ETA: 0s - loss: 1.7295e-04 - mean_absolute_error: 0.0111
# Epoch 00374: val_loss did not improve from 0.00007
# 33/33 [==============================] - 3s 92ms/step - loss: 1.7295e-04 - mean_absolute_error: 0.0111 - val_loss: 1.4011e-04 - val_mean_absolute_error: 0.0120
# Epoch 375/400
# 33/33 [==============================] - ETA: 0s - loss: 1.1838e-04 - mean_absolute_error: 0.0100
# Epoch 00375: val_loss improved from 0.00007 to 0.00006, saving model to results/2020-12-02_TSLA-huber_loss-adam-LSTM-seq-20-step-10-layers-3-units-256-b.h5
# 33/33 [==============================] - 3s 91ms/step - loss: 1.1838e-04 - mean_absolute_error: 0.0100 - val_loss: 6.4355e-05 - val_mean_absolute_error: 0.0071
# Epoch 376/400
# 33/33 [==============================] - ETA: 0s - loss: 1.0965e-04 - mean_absolute_error: 0.0095
# Epoch 00376: val_loss did not improve from 0.00006
# 33/33 [==============================] - 3s 92ms/step - loss: 1.0965e-04 - mean_absolute_error: 0.0095 - val_loss: 8.7911e-05 - val_mean_absolute_error: 0.0079
# Epoch 377/400
# 33/33 [==============================] - ETA: 0s - loss: 1.1594e-04 - mean_absolute_error: 0.0096
# Epoch 00377: val_loss did not improve from 0.00006
# 33/33 [==============================] - 3s 91ms/step - loss: 1.1594e-04 - mean_absolute_error: 0.0096 - val_loss: 1.2355e-04 - val_mean_absolute_error: 0.0085
# Epoch 378/400
# 33/33 [==============================] - ETA: 0s - loss: 1.6341e-04 - mean_absolute_error: 0.0101
# Epoch 00378: val_loss did not improve from 0.00006
# 33/33 [==============================] - 3s 92ms/step - loss: 1.6341e-04 - mean_absolute_error: 0.0101 - val_loss: 8.5091e-05 - val_mean_absolute_error: 0.0091
# Epoch 379/400
# 33/33 [==============================] - ETA: 0s - loss: 1.4004e-04 - mean_absolute_error: 0.0100
# Epoch 00379: val_loss did not improve from 0.00006
# 33/33 [==============================] - 3s 91ms/step - loss: 1.4004e-04 - mean_absolute_error: 0.0100 - val_loss: 8.7124e-05 - val_mean_absolute_error: 0.0083
# Epoch 380/400
# 33/33 [==============================] - ETA: 0s - loss: 1.6782e-04 - mean_absolute_error: 0.0100
# Epoch 00380: val_loss did not improve from 0.00006
# 33/33 [==============================] - 3s 91ms/step - loss: 1.6782e-04 - mean_absolute_error: 0.0100 - val_loss: 8.2215e-05 - val_mean_absolute_error: 0.0074
# Epoch 381/400
# 33/33 [==============================] - ETA: 0s - loss: 1.2817e-04 - mean_absolute_error: 0.0097
# Epoch 00381: val_loss did not improve from 0.00006
# 33/33 [==============================] - 3s 90ms/step - loss: 1.2817e-04 - mean_absolute_error: 0.0097 - val_loss: 7.4085e-05 - val_mean_absolute_error: 0.0070
# Epoch 382/400
# 33/33 [==============================] - ETA: 0s - loss: 1.8269e-04 - mean_absolute_error: 0.0104
# Epoch 00382: val_loss did not improve from 0.00006
# 33/33 [==============================] - 3s 91ms/step - loss: 1.8269e-04 - mean_absolute_error: 0.0104 - val_loss: 1.1197e-04 - val_mean_absolute_error: 0.0089
# Epoch 383/400
# 33/33 [==============================] - ETA: 0s - loss: 1.2870e-04 - mean_absolute_error: 0.0096
# Epoch 00383: val_loss did not improve from 0.00006
# 33/33 [==============================] - 3s 91ms/step - loss: 1.2870e-04 - mean_absolute_error: 0.0096 - val_loss: 9.7177e-05 - val_mean_absolute_error: 0.0084
# Epoch 384/400
# 33/33 [==============================] - ETA: 0s - loss: 1.1492e-04 - mean_absolute_error: 0.0091
# Epoch 00384: val_loss did not improve from 0.00006
# 33/33 [==============================] - 3s 92ms/step - loss: 1.1492e-04 - mean_absolute_error: 0.0091 - val_loss: 6.9806e-05 - val_mean_absolute_error: 0.0069
# Epoch 385/400
# 33/33 [==============================] - ETA: 0s - loss: 1.0083e-04 - mean_absolute_error: 0.0090
# Epoch 00385: val_loss did not improve from 0.00006
# 33/33 [==============================] - 3s 91ms/step - loss: 1.0083e-04 - mean_absolute_error: 0.0090 - val_loss: 6.6417e-05 - val_mean_absolute_error: 0.0070
# Epoch 386/400
# 33/33 [==============================] - ETA: 0s - loss: 1.1728e-04 - mean_absolute_error: 0.0094
# Epoch 00386: val_loss did not improve from 0.00006
# 33/33 [==============================] - 3s 91ms/step - loss: 1.1728e-04 - mean_absolute_error: 0.0094 - val_loss: 8.0069e-05 - val_mean_absolute_error: 0.0073
# Epoch 387/400
# 33/33 [==============================] - ETA: 0s - loss: 1.2484e-04 - mean_absolute_error: 0.0095
# Epoch 00387: val_loss improved from 0.00006 to 0.00006, saving model to results/2020-12-02_TSLA-huber_loss-adam-LSTM-seq-20-step-10-layers-3-units-256-b.h5
# 33/33 [==============================] - 3s 92ms/step - loss: 1.2484e-04 - mean_absolute_error: 0.0095 - val_loss: 6.4202e-05 - val_mean_absolute_error: 0.0075
# Epoch 388/400
# 33/33 [==============================] - ETA: 0s - loss: 1.1295e-04 - mean_absolute_error: 0.0091
# Epoch 00388: val_loss did not improve from 0.00006
# 33/33 [==============================] - 3s 93ms/step - loss: 1.1295e-04 - mean_absolute_error: 0.0091 - val_loss: 7.8381e-05 - val_mean_absolute_error: 0.0079
# Epoch 389/400
# 33/33 [==============================] - ETA: 0s - loss: 1.0985e-04 - mean_absolute_error: 0.0092
# Epoch 00389: val_loss did not improve from 0.00006
# 33/33 [==============================] - 3s 92ms/step - loss: 1.0985e-04 - mean_absolute_error: 0.0092 - val_loss: 7.0992e-05 - val_mean_absolute_error: 0.0076
# Epoch 390/400
# 33/33 [==============================] - ETA: 0s - loss: 1.6819e-04 - mean_absolute_error: 0.0101
# Epoch 00390: val_loss improved from 0.00006 to 0.00006, saving model to results/2020-12-02_TSLA-huber_loss-adam-LSTM-seq-20-step-10-layers-3-units-256-b.h5
# 33/33 [==============================] - 3s 91ms/step - loss: 1.6819e-04 - mean_absolute_error: 0.0101 - val_loss: 5.9001e-05 - val_mean_absolute_error: 0.0073
# Epoch 391/400
# 33/33 [==============================] - ETA: 0s - loss: 1.3469e-04 - mean_absolute_error: 0.0095
# Epoch 00391: val_loss did not improve from 0.00006
# 33/33 [==============================] - 3s 92ms/step - loss: 1.3469e-04 - mean_absolute_error: 0.0095 - val_loss: 7.2191e-05 - val_mean_absolute_error: 0.0073
# Epoch 392/400
# 33/33 [==============================] - ETA: 0s - loss: 1.3806e-04 - mean_absolute_error: 0.0095
# Epoch 00392: val_loss did not improve from 0.00006
# 33/33 [==============================] - 3s 91ms/step - loss: 1.3806e-04 - mean_absolute_error: 0.0095 - val_loss: 8.7161e-05 - val_mean_absolute_error: 0.0083
# Epoch 393/400
# 33/33 [==============================] - ETA: 0s - loss: 1.3888e-04 - mean_absolute_error: 0.0096
# Epoch 00393: val_loss did not improve from 0.00006
# 33/33 [==============================] - 3s 92ms/step - loss: 1.3888e-04 - mean_absolute_error: 0.0096 - val_loss: 5.9108e-05 - val_mean_absolute_error: 0.0071
# Epoch 394/400
# 33/33 [==============================] - ETA: 0s - loss: 1.1664e-04 - mean_absolute_error: 0.0092
# Epoch 00394: val_loss did not improve from 0.00006
# 33/33 [==============================] - 3s 92ms/step - loss: 1.1664e-04 - mean_absolute_error: 0.0092 - val_loss: 6.7248e-05 - val_mean_absolute_error: 0.0070
# Epoch 395/400
# 33/33 [==============================] - ETA: 0s - loss: 1.1277e-04 - mean_absolute_error: 0.0096
# Epoch 00395: val_loss did not improve from 0.00006
# 33/33 [==============================] - 3s 90ms/step - loss: 1.1277e-04 - mean_absolute_error: 0.0096 - val_loss: 9.6373e-05 - val_mean_absolute_error: 0.0085
# Epoch 396/400
# 33/33 [==============================] - ETA: 0s - loss: 1.2722e-04 - mean_absolute_error: 0.0100
# Epoch 00396: val_loss did not improve from 0.00006
# 33/33 [==============================] - 3s 91ms/step - loss: 1.2722e-04 - mean_absolute_error: 0.0100 - val_loss: 6.0818e-05 - val_mean_absolute_error: 0.0077
# Epoch 397/400
# 33/33 [==============================] - ETA: 0s - loss: 1.2802e-04 - mean_absolute_error: 0.0096
# Epoch 00397: val_loss did not improve from 0.00006
# 33/33 [==============================] - 3s 91ms/step - loss: 1.2802e-04 - mean_absolute_error: 0.0096 - val_loss: 1.0054e-04 - val_mean_absolute_error: 0.0104
# Epoch 398/400
# 33/33 [==============================] - ETA: 0s - loss: 1.3495e-04 - mean_absolute_error: 0.0100
# Epoch 00398: val_loss did not improve from 0.00006
# 33/33 [==============================] - 3s 91ms/step - loss: 1.3495e-04 - mean_absolute_error: 0.0100 - val_loss: 9.1939e-05 - val_mean_absolute_error: 0.0097
# Epoch 399/400
# 33/33 [==============================] - ETA: 0s - loss: 9.6537e-05 - mean_absolute_error: 0.0088
# Epoch 00399: val_loss did not improve from 0.00006
# 33/33 [==============================] - 3s 91ms/step - loss: 9.6537e-05 - mean_absolute_error: 0.0088 - val_loss: 7.9844e-05 - val_mean_absolute_error: 0.0072
# Epoch 400/400
# 33/33 [==============================] - ETA: 0s - loss: 1.1230e-04 - mean_absolute_error: 0.0090
# Epoch 00400: val_loss did not improve from 0.00006
# 33/33 [==============================] - 3s 91ms/step - loss: 1.1230e-04 - mean_absolute_error: 0.0090 - val_loss: 1.0662e-04 - val_mean_absolute_error: 0.0091

# %%
data = load_data(ticker, N_STEPS, lookup_step=LOOKUP_STEP, test_size=TEST_SIZE,
                feature_columns=FEATURE_COLUMNS, shuffle=False)
# construct the model
# model = create_model(N_STEPS, loss=LOSS, units=UNITS, cell=CELL, n_layers=N_LAYERS,
#                     dropout=DROPOUT, optimizer=OPTIMIZER, bidirectional=BIDIRECTIONAL)
model_path = os.path.join("results", model_name) + ".h5"
# model.load_weights(model_path)

# %%
# evaluate the model
mse, mae = model.evaluate(data["X_test"], data["y_test"], verbose=0)
# calculate the mean absolute error (inverse scaling)
mean_absolute_error = data["column_scaler"]["adjclose"].inverse_transform([[mae]])[0][0]
print("Mean Absolute Error:", mean_absolute_error)
# Out:
# Mean Absolute Error: 12.638301339273482

# %%
def predict(model, data):
    # retrieve the last sequence from data
    last_sequence = data["last_sequence"][-N_STEPS:]
    # retrieve the column scalers
    column_scaler = data["column_scaler"]
    # reshape the last sequence
    last_sequence = last_sequence.reshape((last_sequence.shape[1], last_sequence.shape[0]))
    # expand dimension
    last_sequence = np.expand_dims(last_sequence, axis=0)
    # get the prediction (scaled from 0 to 1)
    prediction = model.predict(last_sequence)
    # get the price (by inverting the scaling)
    predicted_price = column_scaler["adjclose"].inverse_transform(prediction)[0][0]
    return predicted_price

# %%
# predict the future price
future_price = predict(model, data)
print(f"The price in {LOOKUP_STEP} days will be ${future_price:.2f}.")
# Out:
# The price in 10 days will be $519.78.

# %%
def plot_graph(model, data):
    y_test = data["y_test"]
    X_test = data["X_test"]
    y_pred = model.predict(X_test)
    y_test = np.squeeze(data["column_scaler"]["adjclose"].inverse_transform(np.expand_dims(y_test, axis=0)))
    y_pred = np.squeeze(data["column_scaler"]["adjclose"].inverse_transform(y_pred))
    # last 200 days, feel free to edit that
    plt.plot(y_test[-200:], c='b')
    plt.plot(y_pred[-200:], c='r')
    plt.xlabel("Days")
    plt.ylabel("Price")
    plt.legend(["Actual Price", "Predicted Price"])
    plt.show()

# %%
plt.figure(figsize=(10, 6))

plot_graph(model, data)

# %%
def get_accuracy(model, data):
    y_test = data["y_test"]
    X_test = data["X_test"]
    y_pred = model.predict(X_test)
    y_test = np.squeeze(data["column_scaler"]["adjclose"].inverse_transform(np.expand_dims(y_test, axis=0)))
    y_pred = np.squeeze(data["column_scaler"]["adjclose"].inverse_transform(y_pred))
    print(y_test)
    y_pred = list(map(lambda current, future: int(float(future) > float(current)), y_test[:-LOOKUP_STEP], y_pred[LOOKUP_STEP:]))
    y_test = list(map(lambda current, future: int(float(future) > float(current)), y_test[:-LOOKUP_STEP], y_test[LOOKUP_STEP:]))
    return accuracy_score(y_test, y_pred)

# %%
print(str(LOOKUP_STEP) + ":", "Accuracy Score:", get_accuracy(model, data))
# Out:
# [ 70.27999878  70.10199738  66.2559967   67.7460022   68.80000305
#   69.68800354  70.86199951  70.69400024  69.4980011   67.63800049
#   65.16600037  69.19999695  68.78399658  69.5739975   68.23400116
#   70.09600067  71.69799805  71.94000244  72.61199951  71.59400177
#   73.02999878  73.35199738  73.31999969  75.35800171  73.14199829
#   69.68399811  67.40599823  66.59400177  63.07600021  63.95399857
#   59.07799911  65.21800232  63.22600174  66.77400208  66.55999756
#   62.02399826  60.0719986   63.5379982   66.99199677  67.06999969
#   67.70600128  68.9940033   69.45200348  66.87999725  68.88600159
#   69.20999908  69.46199799  60.45199966  59.7840004   57.51800156
#   58.30199814  59.40800095  59.27600098  59.49200058  61.75400162
#   61.40399933  62.44200134  62.57799911  64.26999664  63.44400024
#   61.5019989   61.15999985  62.56800079  62.36199951  61.63399887
#   60.75400162  61.57600021  61.12799835  60.51200104  58.24599838
#   58.94200134  59.75400162  59.5719986   62.94800186  63.97600174
#   58.95800018  57.0719986   55.30799866  55.2480011   55.31800079
#   56.82799911  58.18399811  56.67200089  57.79199982  57.99200058
#   55.08599854  53.89799881  53.49399948  54.72000122  54.80400085
#   52.90599823  52.08399963  53.55400085  54.9659996   55.72399902
#   55.97200012  57.83599854  57.17599869  58.36199951  53.55599976
#   54.99200058  54.63999939  54.4620018   55.2120018   53.68399811
#   53.54000092  53.27600098  54.67200089  54.24599838  54.65200043
#   52.54999924  52.77999878  51.73199844  49.52600098  47.02799988
#   48.29399872  47.73799896  46.80199814  48.81999969  51.00600052
#   51.06800079  49.41199875  48.9679985   48.39599991  47.90399933
#   45.40200043  46.4620018   46.38999939  45.66600037  42.20600128
#   41.0719986   41.01599884  38.54600143  39.09799957  38.12599945
#   37.74000168  37.97200012  37.64400101  37.0320015   35.79399872
#   38.72000122  39.31800079  41.18999863  40.90000153  42.57600021
#   43.41999817  41.85200119  42.7820015   42.98400116  45.00600052
#   44.94800186  45.2859993   43.92399979  44.37200165  44.72800064
#   43.95199966  43.85400009  44.56800079  44.69200134  45.43399811
#   44.90999985  46.97999954  46.61999893  46.06800079  46.01200104
#   47.7840004   47.72000122  49.01599884  50.70000076  50.47600174
#   50.97200012  50.70800018  51.63600159  51.13600159  52.0340004
#   52.97600174  45.76399994  45.60800171  47.15399933  48.45199966
#   48.3219986   46.77000046  46.86800003  45.66400146  46.15000153
#   46.68399811  47.65999985  47.0019989   45.80199814  47.
#   43.92399979  43.12799835  43.98799896  45.36600113  45.17200089
#   44.16600037  44.43000031  42.27999878  43.          42.81600189
#   43.11800003  44.34199905  45.12200165  45.0019989   44.13600159
#   45.91600037  45.49000168  46.35800171  47.10800171  49.41999817
#   49.17399979  49.04000092  48.56200027  48.95800018  48.69800186
#   49.31999969  48.12400055  48.24599838  44.64199829  45.74000168
#   48.51200104  48.42599869  48.17399979  48.93799973  48.62599945
#   46.60599899  46.2859993   47.54399872  48.00999832  48.90599823
#   48.94800186  49.57799911  51.39199829  51.57799911  51.95000076
#   52.39400101  51.38999939  50.70000076  51.11600113  50.93600082
#   59.93600082  65.62599945  65.54199982  63.24399948  63.0019989
#   62.98400116  62.66199875  63.49399948  63.44400024  65.31600189
#   67.10800171  67.4280014   69.01799774  69.98600006  69.22200012
#   69.87000275  70.43399811  69.9980011   71.90399933  70.44400024
#   70.96600342  66.60800171  67.26799774  65.78399658  66.25800323
#   65.98799896  66.97399902  67.23999786  66.60600281  66.0739975
#   67.1780014   67.90599823  69.76799774  70.54000092  71.93599701
#   71.6780014   76.30000305  75.79799652  78.62999725  80.80799866
#   81.11799622  83.84400177  85.05000305  86.18800354  86.0759964
#   82.94000244  83.66600037  86.05200195  88.60199738  90.30799866
#   93.81199646  98.4280014   96.26799774  95.62999725 104.97200012
#  107.58399963 103.69999695 102.69799805 102.09999847 109.44000244
#  113.91200256 114.44000244 112.96399689 111.60399628 113.37999725
#  116.19799805 128.16200256 130.11399841 156.         177.41200256
#  146.94000244 149.79200745 149.61399841 154.2559967  154.87600708
#  153.45799255 160.80000305 160.0059967  171.67999268 183.48399353
#  179.88200378 180.19999695 166.75799561 159.98199463 155.75999451
#  135.80000305 133.5980072  148.72399902 149.102005   149.8999939
#  144.90800476 140.69599915 121.59999847 129.06599426 126.84600067
#  112.11000061 109.3239975   89.01399994  86.04000092  72.2440033
#   85.52799988  85.5059967   86.85800171 101.         107.84999847
#  105.63200378 102.87200165 100.4260025  104.80000305  96.31199646
#   90.89399719  96.0019989  103.2480011  109.08999634 109.76799774
#  114.59999847 130.19000244 141.97799683 145.96600342 149.04200745
#  150.77799988 149.27200317 137.34399414 146.42199707 141.12600708
#  145.02999878 159.75       153.82400513 160.102005   156.37600708
#  140.26400757 152.23800659 153.64199829 156.51600647 156.00799561
#  163.88400269 162.25799561 161.88200378 158.19200134 160.66600037
#  159.83399963 162.72599792 161.602005   163.11199951 165.52000427
#  163.37600708 163.77400208 164.04600525 161.16200256 167.
#  179.61999512 176.31199646 176.59199524 172.87600708 177.13200378
#  189.98399353 188.13400269 205.00999451 194.56799316 187.05599976
#  198.17999268 196.42599487 198.35800171 200.79200745 200.17999268
#  198.86399841 200.35600281 192.16999817 197.19599915 191.94799805
#  201.86999512 215.96200562 223.92599487 241.73199463 274.31600952
#  277.97198486 273.17599487 278.85598755 308.92999268 299.4119873
#  303.35998535 309.20199585 300.12799072 300.16799927 328.6000061
#  313.67199707 318.46600342 302.61401367 283.3999939  307.92001343
#  295.29800415 299.82199097 297.49798584 286.15200806 297.
#  297.3999939  297.0039978  297.91598511 290.54199219 283.71398926
#  274.87799072 310.95199585 324.20001221 330.14199829 367.12799072
#  377.41799927 375.70599365 400.36599731 409.9960022  402.83999634
#  404.66799927 430.63400269 447.75       442.67999268 498.32000732
#  475.04998779 447.36999512 407.         418.32000732 330.20999146
#  366.27999878 371.33999634 372.72000122 419.61999512 449.76000977
#  441.76000977 423.42999268 442.1499939  449.39001465 424.23001099
#  380.35998535 387.79000854 407.33999634 421.20001221 419.07000732
#  429.01000977 448.16000366 415.08999634 425.67999268 413.98001099
#  425.29998779 425.92001343 434.         442.29998779 446.6499939
#  461.29998779 448.88000488 439.67001343 430.82998657 421.94000244
#  422.64001465 425.79000854 420.63000488 420.27999878 424.67999268
#  406.01998901 410.82998657 388.04000854 400.51000977 423.8999939
#  420.98001099 438.08999634 429.95001221 421.26000977 410.35998535
#  417.13000488 411.76000977 408.5        408.08999634 441.60998535
#  486.64001465 499.26998901 489.60998535 521.84997559 555.38000488
#  574.         585.76000977 567.59997559 584.76000977 568.82000732]
# 10: Accuracy Score: 0.6784313725490196
