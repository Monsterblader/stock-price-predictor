# %% [markdown]
# https://www.thepythoncode.com/article/stock-price-prediction-in-python-using-tensorflow-2-and-keras

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, Bidirectional
from tensorflow.keras.callbacks import ModelCheckpoint, TensorBoard
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from yahoo_fin import stock_info as si
from collections import deque

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import time
import os
import random

# %%
# set seed, so we can get the same results after rerunning several times
np.random.seed(314)
tf.random.set_seed(314)
random.seed(314)

# %%
def load_data(ticker, n_steps=50, scale=True, shuffle=True, lookup_step=1, 
                test_size=0.2, feature_columns=['adjclose', 'volume', 'open', 'high', 'low']):
    """
    Loads data from Yahoo Finance source, as well as scaling, shuffling, normalizing and splitting.
    Params:
        ticker (str/pd.DataFrame): the ticker you want to load, examples include AAPL, TESL, etc.
        n_steps (int): the historical sequence length (i.e window size) used to predict, default is 50
        scale (bool): whether to scale prices from 0 to 1, default is True
        shuffle (bool): whether to shuffle the data, default is True
        lookup_step (int): the future lookup step to predict, default is 1 (e.g next day)
        test_size (float): ratio for test data, default is 0.2 (20% testing data)
        feature_columns (list): the list of features to use to feed into the model, default is everything grabbed from yahoo_fin
    """
    # see if ticker is already a loaded stock from yahoo finance
    if isinstance(ticker, str):
        # load it from yahoo_fin library
        df = si.get_data(ticker)
    elif isinstance(ticker, pd.DataFrame):
        # already loaded, use it directly
        df = ticker
    else:
        raise TypeError("ticker can be either a str or a `pd.DataFrame` instances")
    # this will contain all the elements we want to return from this function
    result = {}
    # we will also return the original dataframe itself
    result['df'] = df.copy()
    # make sure that the passed feature_columns exist in the dataframe
    for col in feature_columns:
        assert col in df.columns, f"'{col}' does not exist in the dataframe."
    if scale:
        column_scaler = {}
        # scale the data (prices) from 0 to 1
        for column in feature_columns:
            scaler = preprocessing.MinMaxScaler()
            df[column] = scaler.fit_transform(np.expand_dims(df[column].values, axis=1))
            column_scaler[column] = scaler
        # add the MinMaxScaler instances to the result returned
        result["column_scaler"] = column_scaler
    # add the target column (label) by shifting by `lookup_step`
    df['future'] = df['adjclose'].shift(-lookup_step)
    # last `lookup_step` columns contains NaN in future column
    # get them before droping NaNs
    last_sequence = np.array(df[feature_columns].tail(lookup_step))
    # drop NaNs
    df.dropna(inplace=True)
    sequence_data = []
    sequences = deque(maxlen=n_steps)
    for entry, target in zip(df[feature_columns].values, df['future'].values):
        sequences.append(entry)
        if len(sequences) == n_steps:
            sequence_data.append([np.array(sequences), target])
    # get the last sequence by appending the last `n_step` sequence with `lookup_step` sequence
    # for instance, if n_steps=50 and lookup_step=10, last_sequence should be of 60 (that is 50+10) length
    # this last_sequence will be used to predict future stock prices not available in the dataset
    last_sequence = list(sequences) + list(last_sequence)
    last_sequence = np.array(last_sequence)
    # add to result
    result['last_sequence'] = last_sequence
    # construct the X's and y's
    X, y = [], []
    for seq, target in sequence_data:
        X.append(seq)
        y.append(target)
    # convert to numpy arrays
    X = np.array(X)
    y = np.array(y)
    # reshape X to fit the neural network
    X = X.reshape((X.shape[0], X.shape[2], X.shape[1]))
    # split the dataset
    # result["X_train"], result["X_test"], result["y_train"], result["y_test"] = train_test_split(X, y, 
    #                                                                            test_size=test_size, shuffle=shuffle)
    split_point = int(len(X) * (1 - test_size))
    result["X_train"], result["X_test"], result["y_train"], result["y_test"] = X[:split_point], X[split_point:], y[:split_point], y[split_point:]
    # return the result
    return result

# %%
def create_model(sequence_length, units=256, cell=LSTM, n_layers=2, dropout=0.3,
                loss="mean_absolute_error", optimizer="rmsprop", bidirectional=False):
    model = Sequential()
    for i in range(n_layers):
        if i == 0:
            # first layer
            if bidirectional:
                model.add(Bidirectional(cell(units, return_sequences=True), input_shape=(None, sequence_length)))
            else:
                model.add(cell(units, return_sequences=True, input_shape=(None, sequence_length)))
        elif i == n_layers - 1:
            # last layer
            if bidirectional:
                model.add(Bidirectional(cell(units, return_sequences=False)))
            else:
                model.add(cell(units, return_sequences=False))
        else:
            # hidden layers
            if bidirectional:
                model.add(Bidirectional(cell(units, return_sequences=True)))
            else:
                model.add(cell(units, return_sequences=True))
        # add dropout after each layer
        model.add(Dropout(dropout))
    model.add(Dense(1, activation="linear"))
    model.compile(loss=loss, metrics=["mean_absolute_error"], optimizer=optimizer)
    return model

# %%
# Window size or the sequence length
N_STEPS = 35
# Lookup step, 1 is the next day
LOOKUP_STEP = 10
# test ratio size, 0.2 is 20%
TEST_SIZE = 0.2
# features to use
FEATURE_COLUMNS = ["adjclose", "volume", "open", "high", "low"]
# date now
date_now = time.strftime("%Y-%m-%d")
### model parameters
N_LAYERS = 3
# LSTM cell
CELL = LSTM
# 256 LSTM neurons
UNITS = 256
# 40% dropout
DROPOUT = 0.4
# whether to use bidirectional RNNs
BIDIRECTIONAL = False
### training parameters
# mean absolute error loss
# LOSS = "mae"
# huber loss
LOSS = "huber_loss"
OPTIMIZER = "adam"
BATCH_SIZE = 64
EPOCHS = 400
# Tesla stock market
ticker = "TSLA"
ticker_data_filename = os.path.join("data", f"{ticker}_{date_now}.csv")
# model name to save, making it as unique as possible based on parameters
model_name = f"{date_now}_{ticker}-{LOSS}-{OPTIMIZER}-{CELL.__name__}-seq-{N_STEPS}-step-{LOOKUP_STEP}-layers-{N_LAYERS}-units-{UNITS}"
if BIDIRECTIONAL:
    model_name += "-b"

# %%
# create these folders if they does not exist
if not os.path.isdir("results"):
    os.mkdir("results")
if not os.path.isdir("logs"):
    os.mkdir("logs")
if not os.path.isdir("data"):
    os.mkdir("data")

# %%
# load the data
data = load_data(ticker, N_STEPS, lookup_step=LOOKUP_STEP, test_size=TEST_SIZE, feature_columns=FEATURE_COLUMNS)
# save the dataframe
data["df"].to_csv(ticker_data_filename)
# construct the model
model = create_model(N_STEPS, loss=LOSS, units=UNITS, cell=CELL, n_layers=N_LAYERS,
                    dropout=DROPOUT, optimizer=OPTIMIZER, bidirectional=BIDIRECTIONAL)
# some tensorflow callbacks
checkpointer = ModelCheckpoint(os.path.join("results", model_name + ".h5"), save_weights_only=True, save_best_only=True, verbose=1)
tensorboard = TensorBoard(log_dir=os.path.join("logs", model_name))
history = model.fit(data["X_train"], data["y_train"],
                    batch_size=BATCH_SIZE,
                    epochs=EPOCHS,
                    validation_data=(data["X_test"], data["y_test"]),
                    callbacks=[checkpointer, tensorboard],
                    verbose=1)
model.save(os.path.join("results", model_name) + ".h5")
# Out:
# _error: 0.0058
# Epoch 00338: val_loss did not improve from 0.00353
# 33/33 [==============================] - 1s 32ms/step - loss: 2.7871e-05 - mean_absolute_error: 0.0058 - val_loss: 0.0106 - val_mean_absolute_error: 0.0811
# Epoch 339/400
# 31/33 [===========================>..] - ETA: 0s - loss: 2.5861e-05 - mean_absolute_error: 0.0054
# Epoch 00339: val_loss did not improve from 0.00353
# 33/33 [==============================] - 1s 32ms/step - loss: 2.5776e-05 - mean_absolute_error: 0.0054 - val_loss: 0.0100 - val_mean_absolute_error: 0.0783
# Epoch 340/400
# 31/33 [===========================>..] - ETA: 0s - loss: 2.3864e-05 - mean_absolute_error: 0.0053
# Epoch 00340: val_loss did not improve from 0.00353
# 33/33 [==============================] - 1s 33ms/step - loss: 2.4110e-05 - mean_absolute_error: 0.0053 - val_loss: 0.0087 - val_mean_absolute_error: 0.0732
# Epoch 341/400
# 31/33 [===========================>..] - ETA: 0s - loss: 2.4048e-05 - mean_absolute_error: 0.0052
# Epoch 00341: val_loss did not improve from 0.00353
# 33/33 [==============================] - 1s 32ms/step - loss: 2.3875e-05 - mean_absolute_error: 0.0052 - val_loss: 0.0093 - val_mean_absolute_error: 0.0758
# Epoch 342/400
# 31/33 [===========================>..] - ETA: 0s - loss: 2.2824e-05 - mean_absolute_error: 0.0051
# Epoch 00342: val_loss did not improve from 0.00353
# 33/33 [==============================] - 1s 32ms/step - loss: 2.3211e-05 - mean_absolute_error: 0.0052 - val_loss: 0.0097 - val_mean_absolute_error: 0.0775
# Epoch 343/400
# 31/33 [===========================>..] - ETA: 0s - loss: 2.4877e-05 - mean_absolute_error: 0.0054
# Epoch 00343: val_loss did not improve from 0.00353
# 33/33 [==============================] - 1s 32ms/step - loss: 2.5109e-05 - mean_absolute_error: 0.0054 - val_loss: 0.0104 - val_mean_absolute_error: 0.0805
# Epoch 344/400
# 31/33 [===========================>..] - ETA: 0s - loss: 2.5162e-05 - mean_absolute_error: 0.0054
# Epoch 00344: val_loss did not improve from 0.00353
# 33/33 [==============================] - 1s 32ms/step - loss: 2.4946e-05 - mean_absolute_error: 0.0054 - val_loss: 0.0100 - val_mean_absolute_error: 0.0790
# Epoch 345/400
# 31/33 [===========================>..] - ETA: 0s - loss: 2.4665e-05 - mean_absolute_error: 0.0053
# Epoch 00345: val_loss did not improve from 0.00353
# 33/33 [==============================] - 1s 33ms/step - loss: 2.4612e-05 - mean_absolute_error: 0.0053 - val_loss: 0.0097 - val_mean_absolute_error: 0.0774
# Epoch 346/400
# 31/33 [===========================>..] - ETA: 0s - loss: 2.3038e-05 - mean_absolute_error: 0.0051
# Epoch 00346: val_loss did not improve from 0.00353
# 33/33 [==============================] - 1s 32ms/step - loss: 2.2982e-05 - mean_absolute_error: 0.0051 - val_loss: 0.0098 - val_mean_absolute_error: 0.0778
# Epoch 347/400
# 31/33 [===========================>..] - ETA: 0s - loss: 2.4414e-05 - mean_absolute_error: 0.0052
# Epoch 00347: val_loss did not improve from 0.00353
# 33/33 [==============================] - 1s 32ms/step - loss: 2.4071e-05 - mean_absolute_error: 0.0052 - val_loss: 0.0107 - val_mean_absolute_error: 0.0815
# Epoch 348/400
# 31/33 [===========================>..] - ETA: 0s - loss: 2.2816e-05 - mean_absolute_error: 0.0051
# Epoch 00348: val_loss did not improve from 0.00353
# 33/33 [==============================] - 1s 32ms/step - loss: 2.2928e-05 - mean_absolute_error: 0.0051 - val_loss: 0.0098 - val_mean_absolute_error: 0.0781
# Epoch 349/400
# 31/33 [===========================>..] - ETA: 0s - loss: 2.4075e-05 - mean_absolute_error: 0.0053
# Epoch 00349: val_loss did not improve from 0.00353
# 33/33 [==============================] - 1s 32ms/step - loss: 2.4336e-05 - mean_absolute_error: 0.0053 - val_loss: 0.0083 - val_mean_absolute_error: 0.0711
# Epoch 350/400
# 31/33 [===========================>..] - ETA: 0s - loss: 2.7487e-05 - mean_absolute_error: 0.0057
# Epoch 00350: val_loss did not improve from 0.00353
# 33/33 [==============================] - 1s 32ms/step - loss: 2.7780e-05 - mean_absolute_error: 0.0057 - val_loss: 0.0102 - val_mean_absolute_error: 0.0796
# Epoch 351/400
# 31/33 [===========================>..] - ETA: 0s - loss: 2.4370e-05 - mean_absolute_error: 0.0052
# Epoch 00351: val_loss did not improve from 0.00353
# 33/33 [==============================] - 1s 32ms/step - loss: 2.4307e-05 - mean_absolute_error: 0.0052 - val_loss: 0.0101 - val_mean_absolute_error: 0.0790
# Epoch 352/400
# 31/33 [===========================>..] - ETA: 0s - loss: 2.4926e-05 - mean_absolute_error: 0.0054
# Epoch 00352: val_loss did not improve from 0.00353
# 33/33 [==============================] - 1s 32ms/step - loss: 2.5037e-05 - mean_absolute_error: 0.0054 - val_loss: 0.0102 - val_mean_absolute_error: 0.0794
# Epoch 353/400
# 31/33 [===========================>..] - ETA: 0s - loss: 2.2297e-05 - mean_absolute_error: 0.0051
# Epoch 00353: val_loss did not improve from 0.00353
# 33/33 [==============================] - 1s 32ms/step - loss: 2.2868e-05 - mean_absolute_error: 0.0051 - val_loss: 0.0097 - val_mean_absolute_error: 0.0774
# Epoch 354/400
# 31/33 [===========================>..] - ETA: 0s - loss: 2.4252e-05 - mean_absolute_error: 0.0053
# Epoch 00354: val_loss did not improve from 0.00353
# 33/33 [==============================] - 1s 32ms/step - loss: 2.4232e-05 - mean_absolute_error: 0.0053 - val_loss: 0.0101 - val_mean_absolute_error: 0.0790
# Epoch 355/400
# 31/33 [===========================>..] - ETA: 0s - loss: 2.4782e-05 - mean_absolute_error: 0.0053
# Epoch 00355: val_loss did not improve from 0.00353
# 33/33 [==============================] - 1s 32ms/step - loss: 2.4514e-05 - mean_absolute_error: 0.0053 - val_loss: 0.0114 - val_mean_absolute_error: 0.0843
# Epoch 356/400
# 31/33 [===========================>..] - ETA: 0s - loss: 2.4470e-05 - mean_absolute_error: 0.0053
# Epoch 00356: val_loss did not improve from 0.00353
# 33/33 [==============================] - 1s 32ms/step - loss: 2.4337e-05 - mean_absolute_error: 0.0053 - val_loss: 0.0097 - val_mean_absolute_error: 0.0772
# Epoch 357/400
# 31/33 [===========================>..] - ETA: 0s - loss: 2.3502e-05 - mean_absolute_error: 0.0052
# Epoch 00357: val_loss did not improve from 0.00353
# 33/33 [==============================] - 1s 32ms/step - loss: 2.3528e-05 - mean_absolute_error: 0.0052 - val_loss: 0.0108 - val_mean_absolute_error: 0.0822
# Epoch 358/400
# 31/33 [===========================>..] - ETA: 0s - loss: 2.5121e-05 - mean_absolute_error: 0.0054
# Epoch 00358: val_loss did not improve from 0.00353
# 33/33 [==============================] - 1s 33ms/step - loss: 2.5142e-05 - mean_absolute_error: 0.0054 - val_loss: 0.0094 - val_mean_absolute_error: 0.0762
# Epoch 359/400
# 31/33 [===========================>..] - ETA: 0s - loss: 2.7500e-05 - mean_absolute_error: 0.0056
# Epoch 00359: val_loss did not improve from 0.00353
# 33/33 [==============================] - 1s 32ms/step - loss: 2.7074e-05 - mean_absolute_error: 0.0056 - val_loss: 0.0100 - val_mean_absolute_error: 0.0788
# Epoch 360/400
# 31/33 [===========================>..] - ETA: 0s - loss: 2.4233e-05 - mean_absolute_error: 0.0053
# Epoch 00360: val_loss did not improve from 0.00353
# 33/33 [==============================] - 1s 33ms/step - loss: 2.4075e-05 - mean_absolute_error: 0.0053 - val_loss: 0.0104 - val_mean_absolute_error: 0.0802
# Epoch 361/400
# 31/33 [===========================>..] - ETA: 0s - loss: 2.5966e-05 - mean_absolute_error: 0.0055
# Epoch 00361: val_loss did not improve from 0.00353
# 33/33 [==============================] - 1s 33ms/step - loss: 2.5907e-05 - mean_absolute_error: 0.0054 - val_loss: 0.0093 - val_mean_absolute_error: 0.0755
# Epoch 362/400
# 31/33 [===========================>..] - ETA: 0s - loss: 2.5429e-05 - mean_absolute_error: 0.0053
# Epoch 00362: val_loss did not improve from 0.00353
# 33/33 [==============================] - 1s 33ms/step - loss: 2.5519e-05 - mean_absolute_error: 0.0053 - val_loss: 0.0102 - val_mean_absolute_error: 0.0797
# Epoch 363/400
# 31/33 [===========================>..] - ETA: 0s - loss: 2.3025e-05 - mean_absolute_error: 0.0051
# Epoch 00363: val_loss did not improve from 0.00353
# 33/33 [==============================] - 1s 33ms/step - loss: 2.2957e-05 - mean_absolute_error: 0.0051 - val_loss: 0.0105 - val_mean_absolute_error: 0.0810
# Epoch 364/400
# 33/33 [==============================] - ETA: 0s - loss: 2.4733e-05 - mean_absolute_error: 0.0053
# Epoch 00364: val_loss did not improve from 0.00353
# 33/33 [==============================] - 1s 33ms/step - loss: 2.4733e-05 - mean_absolute_error: 0.0053 - val_loss: 0.0102 - val_mean_absolute_error: 0.0798
# Epoch 365/400
# 31/33 [===========================>..] - ETA: 0s - loss: 2.6522e-05 - mean_absolute_error: 0.0056
# Epoch 00365: val_loss did not improve from 0.00353
# 33/33 [==============================] - 1s 33ms/step - loss: 2.6684e-05 - mean_absolute_error: 0.0056 - val_loss: 0.0108 - val_mean_absolute_error: 0.0819
# Epoch 366/400
# 31/33 [===========================>..] - ETA: 0s - loss: 2.4867e-05 - mean_absolute_error: 0.0053
# Epoch 00366: val_loss did not improve from 0.00353
# 33/33 [==============================] - 1s 33ms/step - loss: 2.4820e-05 - mean_absolute_error: 0.0053 - val_loss: 0.0099 - val_mean_absolute_error: 0.0782
# Epoch 367/400
# 31/33 [===========================>..] - ETA: 0s - loss: 2.4063e-05 - mean_absolute_error: 0.0053
# Epoch 00367: val_loss did not improve from 0.00353
# 33/33 [==============================] - 1s 33ms/step - loss: 2.3914e-05 - mean_absolute_error: 0.0053 - val_loss: 0.0092 - val_mean_absolute_error: 0.0749
# Epoch 368/400
# 31/33 [===========================>..] - ETA: 0s - loss: 2.4177e-05 - mean_absolute_error: 0.0052
# Epoch 00368: val_loss did not improve from 0.00353
# 33/33 [==============================] - 1s 33ms/step - loss: 2.4368e-05 - mean_absolute_error: 0.0053 - val_loss: 0.0103 - val_mean_absolute_error: 0.0799
# Epoch 369/400
# 31/33 [===========================>..] - ETA: 0s - loss: 2.3087e-05 - mean_absolute_error: 0.0051
# Epoch 00369: val_loss did not improve from 0.00353
# 33/33 [==============================] - 1s 33ms/step - loss: 2.2772e-05 - mean_absolute_error: 0.0051 - val_loss: 0.0091 - val_mean_absolute_error: 0.0745
# Epoch 370/400
# 31/33 [===========================>..] - ETA: 0s - loss: 2.4238e-05 - mean_absolute_error: 0.0051
# Epoch 00370: val_loss did not improve from 0.00353
# 33/33 [==============================] - 1s 33ms/step - loss: 2.3927e-05 - mean_absolute_error: 0.0051 - val_loss: 0.0094 - val_mean_absolute_error: 0.0759
# Epoch 371/400
# 31/33 [===========================>..] - ETA: 0s - loss: 2.3970e-05 - mean_absolute_error: 0.0053
# Epoch 00371: val_loss did not improve from 0.00353
# 33/33 [==============================] - 1s 33ms/step - loss: 2.3957e-05 - mean_absolute_error: 0.0053 - val_loss: 0.0102 - val_mean_absolute_error: 0.0796
# Epoch 372/400
# 31/33 [===========================>..] - ETA: 0s - loss: 2.4386e-05 - mean_absolute_error: 0.0053
# Epoch 00372: val_loss did not improve from 0.00353
# 33/33 [==============================] - 1s 33ms/step - loss: 2.4279e-05 - mean_absolute_error: 0.0053 - val_loss: 0.0109 - val_mean_absolute_error: 0.0823
# Epoch 373/400
# 31/33 [===========================>..] - ETA: 0s - loss: 2.3859e-05 - mean_absolute_error: 0.0052
# Epoch 00373: val_loss did not improve from 0.00353
# 33/33 [==============================] - 1s 33ms/step - loss: 2.3666e-05 - mean_absolute_error: 0.0052 - val_loss: 0.0096 - val_mean_absolute_error: 0.0767
# Epoch 374/400
# 31/33 [===========================>..] - ETA: 0s - loss: 2.4099e-05 - mean_absolute_error: 0.0053
# Epoch 00374: val_loss did not improve from 0.00353
# 33/33 [==============================] - 1s 32ms/step - loss: 2.4116e-05 - mean_absolute_error: 0.0053 - val_loss: 0.0109 - val_mean_absolute_error: 0.0826
# Epoch 375/400
# 31/33 [===========================>..] - ETA: 0s - loss: 2.2531e-05 - mean_absolute_error: 0.0051
# Epoch 00375: val_loss did not improve from 0.00353
# 33/33 [==============================] - 1s 32ms/step - loss: 2.2569e-05 - mean_absolute_error: 0.0051 - val_loss: 0.0105 - val_mean_absolute_error: 0.0806
# Epoch 376/400
# 31/33 [===========================>..] - ETA: 0s - loss: 2.2979e-05 - mean_absolute_error: 0.0052
# Epoch 00376: val_loss did not improve from 0.00353
# 33/33 [==============================] - 1s 32ms/step - loss: 2.2805e-05 - mean_absolute_error: 0.0052 - val_loss: 0.0106 - val_mean_absolute_error: 0.0812
# Epoch 377/400
# 31/33 [===========================>..] - ETA: 0s - loss: 2.3922e-05 - mean_absolute_error: 0.0052
# Epoch 00377: val_loss did not improve from 0.00353
# 33/33 [==============================] - 1s 32ms/step - loss: 2.4101e-05 - mean_absolute_error: 0.0052 - val_loss: 0.0103 - val_mean_absolute_error: 0.0800
# Epoch 378/400
# 31/33 [===========================>..] - ETA: 0s - loss: 2.4222e-05 - mean_absolute_error: 0.0053
# Epoch 00378: val_loss did not improve from 0.00353
# 33/33 [==============================] - 1s 32ms/step - loss: 2.4436e-05 - mean_absolute_error: 0.0053 - val_loss: 0.0119 - val_mean_absolute_error: 0.0863
# Epoch 379/400
# 31/33 [===========================>..] - ETA: 0s - loss: 2.6300e-05 - mean_absolute_error: 0.0055
# Epoch 00379: val_loss did not improve from 0.00353
# 33/33 [==============================] - 1s 33ms/step - loss: 2.6262e-05 - mean_absolute_error: 0.0055 - val_loss: 0.0110 - val_mean_absolute_error: 0.0827
# Epoch 380/400
# 31/33 [===========================>..] - ETA: 0s - loss: 2.2804e-05 - mean_absolute_error: 0.0051
# Epoch 00380: val_loss did not improve from 0.00353
# 33/33 [==============================] - 1s 32ms/step - loss: 2.2801e-05 - mean_absolute_error: 0.0051 - val_loss: 0.0091 - val_mean_absolute_error: 0.0746
# Epoch 381/400
# 31/33 [===========================>..] - ETA: 0s - loss: 2.3721e-05 - mean_absolute_error: 0.0052
# Epoch 00381: val_loss did not improve from 0.00353
# 33/33 [==============================] - 1s 32ms/step - loss: 2.3421e-05 - mean_absolute_error: 0.0051 - val_loss: 0.0094 - val_mean_absolute_error: 0.0759
# Epoch 382/400
# 31/33 [===========================>..] - ETA: 0s - loss: 2.3198e-05 - mean_absolute_error: 0.0051
# Epoch 00382: val_loss did not improve from 0.00353
# 33/33 [==============================] - 1s 32ms/step - loss: 2.3279e-05 - mean_absolute_error: 0.0052 - val_loss: 0.0098 - val_mean_absolute_error: 0.0777
# Epoch 383/400
# 31/33 [===========================>..] - ETA: 0s - loss: 2.3552e-05 - mean_absolute_error: 0.0052
# Epoch 00383: val_loss did not improve from 0.00353
# 33/33 [==============================] - 1s 32ms/step - loss: 2.3586e-05 - mean_absolute_error: 0.0052 - val_loss: 0.0103 - val_mean_absolute_error: 0.0796
# Epoch 384/400
# 31/33 [===========================>..] - ETA: 0s - loss: 2.4269e-05 - mean_absolute_error: 0.0052
# Epoch 00384: val_loss did not improve from 0.00353
# 33/33 [==============================] - 1s 32ms/step - loss: 2.4149e-05 - mean_absolute_error: 0.0052 - val_loss: 0.0098 - val_mean_absolute_error: 0.0778
# Epoch 385/400
# 31/33 [===========================>..] - ETA: 0s - loss: 2.2891e-05 - mean_absolute_error: 0.0051
# Epoch 00385: val_loss did not improve from 0.00353
# 33/33 [==============================] - 1s 32ms/step - loss: 2.2717e-05 - mean_absolute_error: 0.0051 - val_loss: 0.0103 - val_mean_absolute_error: 0.0801
# Epoch 386/400
# 31/33 [===========================>..] - ETA: 0s - loss: 2.3806e-05 - mean_absolute_error: 0.0051
# Epoch 00386: val_loss did not improve from 0.00353
# 33/33 [==============================] - 1s 32ms/step - loss: 2.4000e-05 - mean_absolute_error: 0.0052 - val_loss: 0.0089 - val_mean_absolute_error: 0.0740
# Epoch 387/400
# 31/33 [===========================>..] - ETA: 0s - loss: 2.5659e-05 - mean_absolute_error: 0.0054
# Epoch 00387: val_loss did not improve from 0.00353
# 33/33 [==============================] - 1s 32ms/step - loss: 2.5890e-05 - mean_absolute_error: 0.0054 - val_loss: 0.0099 - val_mean_absolute_error: 0.0784
# Epoch 388/400
# 31/33 [===========================>..] - ETA: 0s - loss: 2.4544e-05 - mean_absolute_error: 0.0054
# Epoch 00388: val_loss did not improve from 0.00353
# 33/33 [==============================] - 1s 33ms/step - loss: 2.4130e-05 - mean_absolute_error: 0.0053 - val_loss: 0.0097 - val_mean_absolute_error: 0.0773
# Epoch 389/400
# 31/33 [===========================>..] - ETA: 0s - loss: 2.4273e-05 - mean_absolute_error: 0.0053
# Epoch 00389: val_loss did not improve from 0.00353
# 33/33 [==============================] - 1s 32ms/step - loss: 2.3855e-05 - mean_absolute_error: 0.0052 - val_loss: 0.0104 - val_mean_absolute_error: 0.0801
# Epoch 390/400
# 31/33 [===========================>..] - ETA: 0s - loss: 2.5126e-05 - mean_absolute_error: 0.0054
# Epoch 00390: val_loss did not improve from 0.00353
# 33/33 [==============================] - 1s 32ms/step - loss: 2.5443e-05 - mean_absolute_error: 0.0054 - val_loss: 0.0095 - val_mean_absolute_error: 0.0766
# Epoch 391/400
# 31/33 [===========================>..] - ETA: 0s - loss: 2.7138e-05 - mean_absolute_error: 0.0056
# Epoch 00391: val_loss did not improve from 0.00353
# 33/33 [==============================] - 1s 33ms/step - loss: 2.7064e-05 - mean_absolute_error: 0.0056 - val_loss: 0.0099 - val_mean_absolute_error: 0.0784
# Epoch 392/400
# 31/33 [===========================>..] - ETA: 0s - loss: 2.4698e-05 - mean_absolute_error: 0.0053
# Epoch 00392: val_loss did not improve from 0.00353
# 33/33 [==============================] - 1s 32ms/step - loss: 2.4493e-05 - mean_absolute_error: 0.0053 - val_loss: 0.0096 - val_mean_absolute_error: 0.0770
# Epoch 393/400
# 31/33 [===========================>..] - ETA: 0s - loss: 2.3992e-05 - mean_absolute_error: 0.0052
# Epoch 00393: val_loss did not improve from 0.00353
# 33/33 [==============================] - 1s 32ms/step - loss: 2.4047e-05 - mean_absolute_error: 0.0052 - val_loss: 0.0099 - val_mean_absolute_error: 0.0782
# Epoch 394/400
# 31/33 [===========================>..] - ETA: 0s - loss: 2.2774e-05 - mean_absolute_error: 0.0051
# Epoch 00394: val_loss did not improve from 0.00353
# 33/33 [==============================] - 1s 33ms/step - loss: 2.2852e-05 - mean_absolute_error: 0.0051 - val_loss: 0.0091 - val_mean_absolute_error: 0.0747
# Epoch 395/400
# 31/33 [===========================>..] - ETA: 0s - loss: 2.4958e-05 - mean_absolute_error: 0.0053
# Epoch 00395: val_loss did not improve from 0.00353
# 33/33 [==============================] - 1s 32ms/step - loss: 2.5098e-05 - mean_absolute_error: 0.0054 - val_loss: 0.0091 - val_mean_absolute_error: 0.0747
# Epoch 396/400
# 31/33 [===========================>..] - ETA: 0s - loss: 2.4442e-05 - mean_absolute_error: 0.0053
# Epoch 00396: val_loss did not improve from 0.00353
# 33/33 [==============================] - 1s 32ms/step - loss: 2.4220e-05 - mean_absolute_error: 0.0052 - val_loss: 0.0101 - val_mean_absolute_error: 0.0790
# Epoch 397/400
# 31/33 [===========================>..] - ETA: 0s - loss: 2.3785e-05 - mean_absolute_error: 0.0053
# Epoch 00397: val_loss did not improve from 0.00353
# 33/33 [==============================] - 1s 33ms/step - loss: 2.4025e-05 - mean_absolute_error: 0.0053 - val_loss: 0.0103 - val_mean_absolute_error: 0.0800
# Epoch 398/400
# 31/33 [===========================>..] - ETA: 0s - loss: 2.4699e-05 - mean_absolute_error: 0.0053
# Epoch 00398: val_loss did not improve from 0.00353
# 33/33 [==============================] - 1s 32ms/step - loss: 2.4675e-05 - mean_absolute_error: 0.0053 - val_loss: 0.0091 - val_mean_absolute_error: 0.0747
# Epoch 399/400
# 31/33 [===========================>..] - ETA: 0s - loss: 2.3979e-05 - mean_absolute_error: 0.0052
# Epoch 00399: val_loss did not improve from 0.00353
# 33/33 [==============================] - 1s 33ms/step - loss: 2.3827e-05 - mean_absolute_error: 0.0052 - val_loss: 0.0103 - val_mean_absolute_error: 0.0803
# Epoch 400/400
# 31/33 [===========================>..] - ETA: 0s - loss: 2.3060e-05 - mean_absolute_error: 0.0052
# Epoch 00400: val_loss did not improve from 0.00353
# 33/33 [==============================] - 1s 32ms/step - loss: 2.3499e-05 - mean_absolute_error: 0.0052 - val_loss: 0.0097 - val_mean_absolute_error: 0.0775

# %%
data = load_data(ticker, N_STEPS, lookup_step=LOOKUP_STEP, test_size=TEST_SIZE,
                feature_columns=FEATURE_COLUMNS, shuffle=False)
# construct the model
# model = create_model(N_STEPS, loss=LOSS, units=UNITS, cell=CELL, n_layers=N_LAYERS,
#                     dropout=DROPOUT, optimizer=OPTIMIZER, bidirectional=BIDIRECTIONAL)
model_path = os.path.join("results", model_name) + ".h5"
# model.load_weights(model_path)

# %%
# evaluate the model
mse, mae = model.evaluate(data["X_test"], data["y_test"], verbose=0)
# calculate the mean absolute error (inverse scaling)
mean_absolute_error = data["column_scaler"]["adjclose"].inverse_transform([[mae]])[0][0]
print("Mean Absolute Error:", mean_absolute_error)
# Out:
# Mean Absolute Error: 48.32080332121808

# %%
def predict(model, data):
    # retrieve the last sequence from data
    last_sequence = data["last_sequence"][-N_STEPS:]
    # retrieve the column scalers
    column_scaler = data["column_scaler"]
    # reshape the last sequence
    last_sequence = last_sequence.reshape((last_sequence.shape[1], last_sequence.shape[0]))
    # expand dimension
    last_sequence = np.expand_dims(last_sequence, axis=0)
    # get the prediction (scaled from 0 to 1)
    prediction = model.predict(last_sequence)
    # get the price (by inverting the scaling)
    predicted_price = column_scaler["adjclose"].inverse_transform(prediction)[0][0]
    return predicted_price

# %%
# predict the future price
future_price = predict(model, data)
print(f"The price in {LOOKUP_STEP} days will be ${future_price:.2f}.")
# Out:
# The price in 10 days will be $274.44.

# %%
def plot_graph(model, data):
    y_test = data["y_test"]
    X_test = data["X_test"]
    y_pred = model.predict(X_test)
    y_test = np.squeeze(data["column_scaler"]["adjclose"].inverse_transform(np.expand_dims(y_test, axis=0)))
    y_pred = np.squeeze(data["column_scaler"]["adjclose"].inverse_transform(y_pred))
    # last 200 days, feel free to edit that
    plt.plot(y_test[-200:], c='b')
    plt.plot(y_pred[-200:], c='r')
    plt.xlabel("Days")
    plt.ylabel("Price")
    plt.legend(["Actual Price", "Predicted Price"])
    plt.show()

# %%
plt.figure(figsize=(10, 6))

plot_graph(model, data)

# %%
def get_accuracy(model, data):
    y_test = data["y_test"]
    X_test = data["X_test"]
    y_pred = model.predict(X_test)
    y_test = np.squeeze(data["column_scaler"]["adjclose"].inverse_transform(np.expand_dims(y_test, axis=0)))
    y_pred = np.squeeze(data["column_scaler"]["adjclose"].inverse_transform(y_pred))
    y_pred = list(map(lambda current, future: int(float(future) > float(current)), y_test[:-LOOKUP_STEP], y_pred[LOOKUP_STEP:]))
    y_test = list(map(lambda current, future: int(float(future) > float(current)), y_test[:-LOOKUP_STEP], y_test[LOOKUP_STEP:]))
    return accuracy_score(y_test, y_pred)

# %%
print(str(LOOKUP_STEP) + ":", "Accuracy Score:", get_accuracy(model, data))
# Out:
# 10: Accuracy Score: 0.398422090729783
